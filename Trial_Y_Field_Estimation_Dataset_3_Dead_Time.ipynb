# %%
import os
import numpy as np
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.animation import FuncAnimation
import seaborn as sns
import cupy as cp  

import time
from scipy.interpolate import RectBivariateSpline, RegularGridInterpolator
from scipy.integrate import simpson 
from ipywidgets import interact, IntSlider

# %%
#file paths
DATA_DIR = r"DataFiles_to_Dinesh_Pranav\Data_files\Simulation\Dataset_3"

#files for longitudinal estimation
SIM_FILES_Longitudinal_Estimation = {
    "time": r"DataFiles_to_Dinesh_Pranav\Data_files\Simulation\Dataset_0\t_array.csv",
    "freq": r"DataFiles_to_Dinesh_Pranav\Data_files\Simulation\Dataset_0\delz_MHz.csv",
    "data": r"DataFiles_to_Dinesh_Pranav\Data_files\Simulation\Dataset_0\transHport_t_vs_Bz_delx_0.01_dely_0.1.csv"
}

#files for y field estimation 
SIM_FILES_CONFIG_Y_Estimation = {
    "time": os.path.join(DATA_DIR, "t_array.csv"),
    "freq": os.path.join(DATA_DIR, "delz_MHz.csv"),
    "by_vals": os.path.join(DATA_DIR, "dely_MHz.csv"),
    # MUST be in the same order as By_values.csv
    "intensities": sorted([
        os.path.join(DATA_DIR, f) for f in os.listdir(DATA_DIR) if f.startswith("transH_t_vs_Bz_alpha2500_delx_0_dely_") and f.endswith(".csv")
    ], key=lambda x: float(x.split("_dely_")[1].split(".csv")[0]))
}



'''SIM_FILES_CONFIG_Y_Estimation = {
    "time": os.path.join(DATA_DIR, "t_array.csv"),
    "freq": os.path.join(DATA_DIR, "delz_MHz.csv"),
    "by_vals": os.path.join(DATA_DIR, "dely_MHz.csv"),
    # MUST be in the same order as By_values.csv
    "intensities": [ 
        os.path.join(DATA_DIR, "transH_t_vs_Bz_alpha2500_delx_0_dely_0.csv"),
        os.path.join(DATA_DIR, "transH_t_vs_Bz_alpha2500_delx_0_dely_0.1.csv"),
        os.path.join(DATA_DIR, "transH_t_vs_Bz_alpha2500_delx_0_dely_0.2.csv"),
        os.path.join(DATA_DIR, "transH_t_vs_Bz_alpha2500_delx_0_dely_0.3.csv"),
        os.path.join(DATA_DIR, "transH_t_vs_Bz_alpha2500_delx_0_dely_0.4.csv"),
        os.path.join(DATA_DIR, "transH_t_vs_Bz_alpha2500_delx_0_dely_0.5.csv")
    ]
}'''

#experimental data
EXP_FILES ={
    "time": r"DataFiles_to_Dinesh_Pranav\Data_files\Experiment\t_exp.csv",
    "freq_axis": r"DataFiles_to_Dinesh_Pranav\Data_files\Experiment\Y_MHz_Exp.csv",
    "data": r"DataFiles_to_Dinesh_Pranav\Data_files\Experiment\Probe_trans_Exp.csv"
}

Test = 10
new_dir = f"Tests/Actual/CW/Test_{Test}"
new_dir_y = f"Tests/Actual/CW/Transverse_Field_Estimation/Test_{Test}"
os.makedirs(new_dir, exist_ok=True)
os.makedirs(new_dir_y, exist_ok=True)

# %%
#z field estimation parameters
#note: i use B_unk even though we are actually characterising f_unk, a gyromagnetic ratio factor is required to convert
B_UNK_BOUND = 1
B_UNK_INITIAL_RANGE = (-B_UNK_BOUND, B_UNK_BOUND) 
INITIAL_RESOLUTION  = 0.001
SIGMA_NOISE = 0.05 

#y field estimation parameters
fixed_bz_estimate = 0.075
fixed_by_estimate = 0.12
b_y_bounds = (0,0.5)
initial_res_by = 0.00025

F_BIAS_OFFSET_NUISANCE = 0
#pulse on threshold, need to align both  the  graphs to t=0
SIM_PULSE_THRESH = 0.2
EXP_PULSE_THRESH = 0.2

# %%
#Adaptive experiment parameters
T_STEP = 0.2 #FIXME: Number of time  point we have/ number of times we wanna loop, so change this value
MAX_TIME = 10 #FIXME: we have the data, just look and paste
KL_Y_GRID_SIZE = 100 #number of points under consideration for KL divergence expectation over hypothetical signal

# %%
#Adaptive zoom parameter
ZOOM_FACTOR = 2.5
ZOOM_TRIGGER_RATIO = 0.2
global ZOOM_TRIGGER_MULTIPLE
ZOOM_TRIGGER_MULTIPLE = 400
#ZOOM_WINDOW_FACTOR  =  100

# %%
#Data loading and pre-processing
def load_simulation(files):
    to = time.time()
    print(f"Loading Simulation from {files['data']}...")
    t = pd.read_csv(files['time'], header = None).values.flatten()
    f = pd.read_csv(files['freq'], header  = None).values.flatten()
    d = pd.read_csv(files['data'], header = None).values

    if d.shape != (len(t),len(f)):
        d = d.T

    d= calibration(d, np.min(d), np.max(d))
    spline = RectBivariateSpline(t, f, d, kx = 1, ky = 1)
    print(time.time()-to, "was the time taken to load sim data.")

    return  t,f,spline

def load_simulation_cube(config):
    print("...Loading Simulation Cube Data...")
    to = time.time()
    t_axis = pd.read_csv(config['time'], header=None).values.flatten()
    f_axis = pd.read_csv(config['freq'], header=None).values.flatten()
    by_axis = pd.read_csv(config['by_vals'], header=None).values.flatten()

    print(f"  > Axes Loaded: Time[{len(t_axis)}], Freq[{len(f_axis)}], By[{len(by_axis)}]")

    matrix_list = []
    for fname in config['intensities']:
        data =  pd.read_csv(fname, header=None).values

        if data.shape != (len(t_axis), len(f_axis)):
            data = data.T
        scale = 1/(np.max(data)-np.min(data))
        calibrated_data = (data-np.min(data))*scale
        calibrated_data = np.clip(calibrated_data,  0.0, 1.0)
        matrix_list.append(calibrated_data)
    
    cube = np.stack(matrix_list, axis=2)
    print(f"  > Cube Built. Final Shape: {cube.shape}")
    print("Time taken to load sim data:", time.time() - to)
    return t_axis, f_axis, by_axis, cube

def load_experiment(files):
    to = time.time()
    print(f"Loading Experiment from {files['data']}...")
    t = pd.read_csv(files['time'], header = None).values.flatten()
    f_bias = pd.read_csv(files['freq_axis'], header  = None).values.flatten()
    raw_data = pd.read_csv(files['data'], header = None).values

    if raw_data.shape != (len(t),len(f_bias)):
        raw_data = raw_data.T

    calibrated_data= calibration(raw_data, np.min(raw_data), np.max(raw_data))
    print(time.time()-to, "was the time taken to load exp data.")
    return t, f_bias, calibrated_data

def calibration(data, v_dark, v_max):
    scale = 1/(v_max-v_dark)
    calibrated_data = (data-v_dark)*scale
    calibrated_data = np.clip(calibrated_data,  0.0, 1.0)

    return calibrated_data


#need to check whether this works 
def find_pulse_start(trace, t_axis, threshold):
    idx = np.where(trace>threshold)[0]
    if len(idx)>0:
        return t_axis[idx[0]], idx[0]
    return t_axis[0], 0

# %%
def plot_heat_and_surface(X_vec, Y_vec, Z_arr, title_prefix="Data", estimation_mode='longitudinal', trajectory_mode = False, traj_bias=[]):
    Xg, Yg = np.meshgrid(X_vec, Y_vec,indexing = 'ij')  # note: meshgrid order (cols = y)
    # heatmap
    plt.figure(figsize=(8,5))
    plt.pcolormesh( Xg, Yg, Z_arr, shading='auto')
    plt.xlabel("Time (x)"); plt.ylabel("Applied Bias Frequency (y)")
    if trajectory_mode: traj_bias = np.repeat(traj_bias, X_vec.shape[0]//len(traj_bias))
    plt.plot(X_vec[:len(traj_bias)], traj_bias, color='red', marker='o', markersize=5, label='Trajectory' if trajectory_mode else "")
    plt.colorbar(label="Z value")
    plt.title(f"{title_prefix} heatmap (rows=time, cols=freq)")
    plt.tight_layout(); plt.show()
    # 3D surface (might be heavy)
    fig = plt.figure(figsize=(9,6))
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(Yg, Xg, Z_arr, cmap=cm.viridis, linewidth=0, antialiased=True)
    ax.set_xlabel("Applied Bias Frequency (y)"); ax.set_ylabel("Time (x)"); ax.set_zlabel("Z value")
    plt.title(f"{title_prefix} 3D surface")
    plt.tight_layout(); plt.show()

def plot_slice(by_idx):
    t_sim, f_sim, by_sim, sim_cube = load_simulation_cube(SIM_FILES_CONFIG_Y_Estimation)
    plt.figure(figsize=(10, 6))
    data_slice = sim_cube[:, :, by_idx].T

    plt.imshow(
        data_slice,
        aspect ='auto',
        origin='lower',
        extent=[t_sim[0], t_sim[-1], f_sim[0], f_sim[-1]],
        cmap='viridis'
    )
    plt.colorbar(label='Intensity')
    plt.title(f"Simulation Slice at By = {by_sim[by_idx]:.2f}")
    plt.xlabel('Time')
    plt.ylabel('Frequency')
    plt.show()

# %%
#interpolator and interpolation validator for Y field estimation
def get_final_interpolator(t, f, by, cube):
    print("...Building Final Interpolator...")
    if not os.path.exists(r"DataFiles_to_Dinesh_Pranav\Data_files\Simulation\Dataset_3\sim_interpolator.pkl"):
        to = time.time()
        full_interp = RegularGridInterpolator(
            (t, f, by),
            cube,
            method='cubic',
            bounds_error=False,
            fill_value=None
        )
        with open(r"DataFiles_to_Dinesh_Pranav\Data_files\Simulation\Dataset_3\sim_interpolator.pkl", 'wb') as file:
            pickle.dump((t, f, by, full_interp), file)

    else:
        to = time.time()
        with open(r"DataFiles_to_Dinesh_Pranav\Data_files\Simulation\Dataset_3\sim_interpolator.pkl", 'rb') as file:
            t_sim, f_sim, by_sim, full_interp = pickle.load(file)

    print("Time taken to load Interpolator:", time.time() - to)
    return full_interp

#interpolator predictions
def get_predictions_batch(interpolator, t_pts, z_vals, y_grid):

    if np.isscalar(z_vals) or z_vals.ndim == 0:     
        T_mesh, Y_mesh = np.meshgrid(t_pts, y_grid, indexing='ij')
        Z_mesh = np.full_like(T_mesh, z_vals)
        query_points = np.stack((T_mesh.flatten(), Z_mesh.flatten(), Y_mesh.flatten()), axis=1)
        predictions = interpolator(query_points)
        return predictions.reshape(T_mesh.shape)
    


    #the two elif conditions are for the case of querying in the longitudinal estimation run
    #with the first elif being used by the KL divergence step and second being used by the likelihood
    #distinction necessary because of the different array shapes based on context
    elif (np.isscalar(y_grid) or y_grid.ndim == 0) and t_pts.ndim == 0:
        # T_mesh, Z_mesh = np.meshgrid(t_pts, z_vals, indexing='ij')
        T_mesh = np.full_like(z_vals, t_pts, dtype=float)
        Z_mesh = z_vals
        Y_mesh = np.full_like(T_mesh, y_grid)
        query_points = np.stack((T_mesh.flatten(), Z_mesh.flatten(), Y_mesh.flatten()), axis=1)
        predictions = interpolator(query_points)
        return predictions.reshape(T_mesh.shape)
    
    elif np.isscalar(y_grid) or y_grid.ndim == 0:
        T_mesh, Z_mesh = np.meshgrid(t_pts, z_vals, indexing='ij')
        Y_mesh = np.full_like(T_mesh, y_grid)
        query_points = np.stack((T_mesh.flatten(), Z_mesh.flatten(), Y_mesh.flatten()), axis=1)
        predictions = interpolator(query_points)
        return predictions.reshape(T_mesh.shape)
    else:
        Z_mesh, Y_mesh = np.meshgrid(z_vals, y_grid, indexing ='ij')
        T_mesh = np.full_like(Z_mesh, t_pts)

        query = np.stack([T_mesh.flatten(), Z_mesh.flatten(), Y_mesh.flatten()], axis = 1)
        predictions = interpolator(query)
        return predictions.reshape(len(z_vals),len(y_grid))

def validate_interpolator(t,f, by, cube, time_idx=-1):
    print("...Validating Interpolator...")
    if time_idx == -1: time_idx = len(t) - 1

    true_surface  = cube[time_idx, :, : ]
    errors = []

    for i in range(len(by)):
        target_by  = by[i]
        true_curve = true_surface[:,i]
        train_by = np.delete(by, i)
        train_data = np.delete(true_surface, i , axis= 1)

        interp = RegularGridInterpolator(
            (f, train_by),
            train_data,
            method ='cubic',
            bounds_error =False,
            fill_value  = None
        )

        query_points = np.zeros((len(f), 2))
        query_points[:, 0] = f
        query_points[:, 1] = target_by

        pred_curve  = interp(query_points)
        mse = np.mean((pred_curve - true_curve)**2)
        rmse  = np.sqrt(mse)

        signal_range = np.max(true_curve) - np.min(true_curve)
        nrmse = rmse/signal_range

        errors.append(nrmse)
        print(f"  Hold-out By={target_by:.1f} | NRMSE: {nrmse*100:.2f}%")

        #if nrmse  > 0.05:
        plt.figure(figsize=(6,3))
        plt.plot(f, true_curve, 'k-', label='True')
        plt.plot(f, pred_curve, 'r--', label='Predicted by Interpolator')
        plt.title(f"Validation at By={target_by:.1f}")
        plt.legend()
        plt.show()
    avg_error = np.mean(errors)
    print(f"--- Average Error: {avg_error*100:.2f}% ---")
    
    if avg_error < 0.05:
        print("PASS: Linear Interpolation is safe (Error < 5%)")
    elif avg_error < 0.10:
        print("WARNING: Linear Interp has 5-10% error. Consider Cubic.")
    else:
        print("FAIL: Significant non-linearity detected. Need more simulation points.")

# %%
#Likelihood and KL for Longtudinal Estimation
def calculate_likelihood_gpu(y_meas, t_sim_abs, current_bias, y_grid, b_grid_gpu, sim_spline, sigma):
    to = time.time()
    b_grid_cpu = cp.asnumpy(b_grid_gpu)
    f_total_query = b_grid_cpu + current_bias

    y_theory_gpu = cp.asarray(get_predictions_batch(sim_spline, t_sim_abs, f_total_query, y_grid))
    y_meas_gpu = cp.asarray(y_meas)

    resid_sq = (y_meas_gpu[:, None] - y_theory_gpu)**2
    sse = cp.sum(resid_sq, axis=0)

    log_L = -sse / (2 * sigma**2)
    print(time.time() - to,"was the time taken to compute the likelihood.|", end=" ")
    #return cp.exp(log_L - cp.max(log_L))
    return cp.exp(log_L)

def calculate_kl_divergence_gpu(posterior_gpu, b_grid_gpu, y_grid, sim_spline, t_next_start, t_next_end, candidate_biases, batch_size = 10):
    to = time.time()
    b_grid_cpu = cp.asnumpy(b_grid_gpu)

    #hypothetical signal
    y_grid_gpu = cp.linspace(0, 1, KL_Y_GRID_SIZE)
    
    # Time point for prediction (Midpoint of next step), rather than doing this across all time, do it for one time stamp, wont make a big difference IG FIXME
    t_mid = (t_next_start + t_next_end) / 2.0

    n_candidates = len(candidate_biases)
    n_grid =len(b_grid_gpu)
    #dB = b_grid_gpu[1] - b_grid_gpu[0]  
    candidate_biases_gpu = cp.array(candidate_biases)
    expected_kl_values = cp.zeros_like(candidate_biases_gpu)

    posterior_gpu_reshaped =  posterior_gpu.reshape(1,1,n_grid)

    for i in range(0, n_candidates, batch_size):
        end = min(i+batch_size, n_candidates)
        batch_candidates = candidate_biases[i:end]
        B_total_batch = batch_candidates[:,None] + b_grid_cpu[None, :]
        mu_cpu = get_predictions_batch(sim_spline, t_mid, B_total_batch, y_grid)
        print(mu_cpu.shape)
        mu_gpu = cp.asarray(mu_cpu) # time x candidates x b_grid # 0

        diff_sq = (y_grid_gpu[None,:,None] - mu_gpu[:,None,:])**2
        L_tensor = cp.exp(-diff_sq / (2 * SIGMA_NOISE**2))
        #P_y = cp.sum(L_tensor * posterior_gpu_reshaped, axis=2) * dB
        P_y = cp.trapz(L_tensor * posterior_gpu_reshaped, x = b_grid_gpu, axis=2) 
        Posterior_tensor = (L_tensor * posterior_gpu_reshaped) / (P_y[:, :, None] + 1e-15)
        log_term = cp.log((Posterior_tensor + 1e-15) / (posterior_gpu_reshaped + 1e-15))
        #KL_per_meas = cp.sum(Posterior_tensor * log_term, axis=2) * dB
        KL_per_meas = cp.trapz(Posterior_tensor * log_term, x = b_grid_gpu,axis=2)
        batch_expected_kl = cp.trapz(P_y * KL_per_meas, x = y_grid_gpu, axis=1)
        expected_kl_values[i:end] = batch_expected_kl
        del L_tensor,Posterior_tensor,diff_sq
        cp.get_default_memory_pool().free_all_blocks()
    
    print(time.time() - to,"was the time taken to compute the KL optimisation.", end=" ")
    return candidate_biases[int(cp.argmax(expected_kl_values))], expected_kl_values

#KL and Likelihood for Y field Estimation
def calculate_likelihood_by(y_meas, t_chunk_sim, current_bias_z, by_grid_cpu, sim_interp, sigma):
    z_total = fixed_bz_estimate + current_bias_z
    y_pred_cpu = get_predictions_batch(sim_interp, t_chunk_sim, z_total, by_grid_cpu)

    y_pred_gpu = cp.asarray(y_pred_cpu)
    y_meas_gpu = cp.asarray(y_meas)

    resid_sq = (y_meas_gpu[:, None] - y_pred_gpu)**2
    sse = cp.sum(resid_sq, axis=0)
    log_L = -sse/(2* sigma**2)
    return cp.exp(log_L - cp.max(log_L))

def calculate_kl_by(posterior_gpu, by_grid_gpu, sim_interp, t_next_start, t_next_end, candidate_biases_z, batch_size = 20):
    t_start = time.time()
    t_mid = (t_next_start + t_next_end) / 2.0
    z_candidates = fixed_bz_estimate + candidate_biases_z
    y_grid_gpu = cp.linspace(0,1, KL_Y_GRID_SIZE)

    n_candidates = len(z_candidates)
    n_grid =len(by_grid_gpu)
    candidate_biases_gpu = cp.array(z_candidates)
    expected_kl = cp.zeros_like(candidate_biases_gpu)

    posterior_gpu_reshaped =  posterior_gpu.reshape(1,1,n_grid)

    for i in range(0, n_candidates, batch_size):
        end = min(i+batch_size, n_candidates)
        batch_candidates = z_candidates[i:end]
        mu_matrix_cpu = get_predictions_batch(sim_interp, t_mid, batch_candidates, by_grid_gpu.get())
        mu_matrix_gpu = cp.asarray(mu_matrix_cpu)

        diff_sq = (mu_matrix_gpu[:,None,:] - y_grid_gpu[None, :, None])**2
        L_tensor = cp.exp(-diff_sq / (2 * SIGMA_NOISE**2))
        P_y = cp.trapz(L_tensor * posterior_gpu_reshaped, x = by_grid_gpu, axis=2) 
        Posterior_tensor = (L_tensor * posterior_gpu_reshaped) / (P_y[:, :, None] + 1e-15)
        log_term = cp.log((Posterior_tensor + 1e-15) / (posterior_gpu_reshaped + 1e-15))
        KL_per_meas = cp.trapz(Posterior_tensor * log_term, x = by_grid_gpu,axis=2)
        batch_expected_kl = cp.trapz(P_y * KL_per_meas, x = y_grid_gpu, axis=1)
        expected_kl[i:end] = batch_expected_kl
        del L_tensor,Posterior_tensor,diff_sq
        cp.get_default_memory_pool().free_all_blocks()

    best_idx = int(cp.argmax(expected_kl))
    best_bias = candidate_biases_z[best_idx]
    print("KL Calculation Time:", time.time() - t_start)
    return best_bias, expected_kl

# %%
#zoom and summary stats
def check_and_apply_zoom(posterior_gpu, b_grid_gpu, current_res):
    #PDF -> CDF
    to = time.time()
    dB = b_grid_gpu[1:] - b_grid_gpu[:-1]
    pdf_mass = cp.zeros_like(posterior_gpu)
    pdf_mass[:-1] = posterior_gpu[:-1] * dB
    pdf_mass[-1] = posterior_gpu[-1] * dB[-1]
    cdf = cp.cumsum(pdf_mass)
    cdf /= cdf[-1] # Ensure it ends exactly at 1.0
    
    #Finding region where majority of the probability is concentrated
    idx_01 = int(cp.searchsorted(cdf, cp.array(1e-5)))
    idx_99 = int(cp.searchsorted(cdf, cp.array(1-1e-5)))
    
    width_idx = idx_99 - idx_01
    total_points = len(b_grid_gpu)
    print(width_idx, end = " ")
    #Check Trigger
    new_res = current_res
    new_b_grid_gpu = b_grid_gpu
    new_posterior_gpu = posterior_gpu
    if ((new_res*ZOOM_TRIGGER_MULTIPLE) > (new_b_grid_gpu[idx_99] - new_b_grid_gpu[idx_01])) or width_idx<100:
        while ((new_res*ZOOM_TRIGGER_MULTIPLE )>(new_b_grid_gpu[idx_99] - new_b_grid_gpu[idx_01])) or width_idx<100:
            print(f"  [ZOOM] Triggered! Mass concentrated in {width_idx} points.|", end =" ")
            
            #Define New Grid resolution
            new_res /= ZOOM_FACTOR
            
            # Create New Grid
            if len(new_b_grid_gpu)<10000: 
                fine_b_grid_gpu = cp.arange(new_b_grid_gpu[idx_01], new_b_grid_gpu[idx_99], new_res)
                new_b_grid_gpu_1 = cp.unique(cp.concatenate((new_b_grid_gpu, fine_b_grid_gpu)))

                new_posterior_gpu_1 = cp.full(new_b_grid_gpu_1.shape, (1/2/B_UNK_BOUND), dtype=new_posterior_gpu.dtype)

                old_indices = cp.searchsorted(new_b_grid_gpu_1, new_b_grid_gpu)
                #indices = cp.clip(indices, 0, len(b_grid_gpu) - 1)
                new_posterior_gpu_1[old_indices]  = new_posterior_gpu 
                normalization = cp.trapz(new_posterior_gpu_1, new_b_grid_gpu_1)
                new_posterior_gpu = new_posterior_gpu_1
                new_b_grid_gpu = new_b_grid_gpu_1
                new_posterior_gpu /= normalization

                dB = new_b_grid_gpu[1:] - new_b_grid_gpu[:-1]
                pdf_mass = cp.zeros_like(new_posterior_gpu)
                pdf_mass[:-1] = new_posterior_gpu[:-1] * dB
                pdf_mass[-1] = new_posterior_gpu[-1] * dB[-1]
                cdf = cp.cumsum(pdf_mass)
                cdf /= cdf[-1] # Ensure it ends exactly at 1.0
                
                #Finding region where majority of the probability is concentrated
                idx_01 = int(cp.searchsorted(cdf, cp.array(1e-5)))
                idx_99 = int(cp.searchsorted(cdf, cp.array(1-1e-5)))
                width_idx = idx_99 - idx_01
                total_points = len(new_b_grid_gpu)
            else:
                new_b_grid_gpu_1 = cp.linspace(new_b_grid_gpu[idx_01], new_b_grid_gpu[idx_99], 4000)
                new_res = float(new_b_grid_gpu_1[1] - new_b_grid_gpu_1[0])
                # 5. Interpolate Posterior (Nearest Left Neighbor)
                # We find which index in OLD grid is just left of each NEW point
                # searchsorted(old, new, side='right') - 1 gives the left neighbor index
                indices = cp.searchsorted(new_b_grid_gpu, new_b_grid_gpu_1, side='right') - 1
                indices = cp.clip(indices, 0, len(new_b_grid_gpu) - 1)
                new_posterior_gpu_1 = new_posterior_gpu[indices]  
                
                normalization = cp.trapz(new_posterior_gpu_1, new_b_grid_gpu_1)
                new_posterior_gpu = new_posterior_gpu_1/normalization
                new_b_grid_gpu = new_b_grid_gpu_1
                dB = new_b_grid_gpu[1:] - new_b_grid_gpu[:-1]
                pdf_mass = cp.zeros_like(new_posterior_gpu)
                pdf_mass[:-1] = new_posterior_gpu[:-1] * dB
                pdf_mass[-1] = new_posterior_gpu[-1] * dB[-1]
                cdf = cp.cumsum(pdf_mass)
                cdf /= cdf[-1] # Ensure it ends exactly at 1.0
                
                #Finding region where majority of the probability is concentrated
                idx_01 = int(cp.searchsorted(cdf, cp.array(1e-5)))
                idx_99 = int(cp.searchsorted(cdf, cp.array(1-1e-5)))
                width_idx = idx_99 - idx_01
                total_points = len(new_b_grid_gpu)
            
        print(f"  [ZOOM] Res: {current_res:.6f} -> {new_res:.6f} | Grid Size: {len(new_b_grid_gpu)}|", end=" ")
        print(time.time() - to,"was the time taken to increase resolution.", end=" ")
        return new_posterior_gpu, new_b_grid_gpu, new_res
    
    # No Zoom
    return posterior_gpu, b_grid_gpu, current_res

def check_and_apply_zoom_by(posterior_gpu, b_grid_gpu, current_res):
    to = time.time()
    #PDF -> CDF
    dB = b_grid_gpu[1:] - b_grid_gpu[:-1]
    pdf_mass = cp.zeros_like(posterior_gpu)
    pdf_mass[:-1] = posterior_gpu[:-1] * dB
    pdf_mass[-1] = posterior_gpu[-1] * dB[-1]
    cdf = cp.cumsum(pdf_mass)
    cdf /= cdf[-1] # Ensure it ends exactly at 1.0

    a = 1e-5
    idx_01 = int(cp.searchsorted(cdf, cp.array(a)))
    idx_99 = int(cp.searchsorted(cdf, cp.array(1-a)))
    width_idx = idx_99 - idx_01
    total_points = len(b_grid_gpu)
    print(idx_01,idx_99,width_idx, end = " ")

    #Check Trigger
    #if idx_99 - idx_01 < (ZOOM_TRIGGER_RATIO * total_points): 
    new_res = current_res
    new_b_grid_gpu = b_grid_gpu
    new_posterior_gpu = posterior_gpu
    if (current_res*ZOOM_TRIGGER_MULTIPLE) > (new_b_grid_gpu[idx_99] - new_b_grid_gpu[idx_01]):
        print(cp.max(new_posterior_gpu))
        while (new_res*ZOOM_TRIGGER_MULTIPLE) > (new_b_grid_gpu[idx_99] - new_b_grid_gpu[idx_01]):
            if new_b_grid_gpu[idx_99] - new_b_grid_gpu[idx_01] < 1e-6:
                a = a**2
            print(f"  [ZOOM] Triggered! Mass concentrated in {width_idx} points.|", end =" ")
            new_res /= ZOOM_FACTOR
            if len(new_b_grid_gpu)<10000: 
                fine_b_grid_gpu = cp.arange(new_b_grid_gpu[idx_01], new_b_grid_gpu[idx_99], new_res)
                print(fine_b_grid_gpu[0], fine_b_grid_gpu[-1], new_res)
                new_b_grid_gpu_1 = cp.unique(cp.concatenate((new_b_grid_gpu, fine_b_grid_gpu)))

                new_posterior_gpu_1 = cp.full(new_b_grid_gpu_1.shape, (1/(b_y_bounds[1] - b_y_bounds[0])), dtype=new_b_grid_gpu_1.dtype)

                old_indices = cp.searchsorted(new_b_grid_gpu_1, new_b_grid_gpu)
                #indices = cp.clip(indices, 0, len(b_grid_gpu) - 1)
                new_posterior_gpu_1[old_indices]  = new_posterior_gpu 
                normalization = cp.trapz(new_posterior_gpu_1, new_b_grid_gpu_1)
                new_posterior_gpu = new_posterior_gpu_1
                new_b_grid_gpu = new_b_grid_gpu_1
                new_posterior_gpu /= normalization

                dB = new_b_grid_gpu[1:] - new_b_grid_gpu[:-1]
                pdf_mass = cp.zeros_like(new_posterior_gpu)
                pdf_mass[:-1] = new_posterior_gpu[:-1] * dB
                pdf_mass[-1] = new_posterior_gpu[-1] * dB[-1]
                cdf = cp.cumsum(pdf_mass)
                cdf /= cdf[-1] # Ensure it ends exactly at 1.0

                idx_01 = int(cp.searchsorted(cdf, cp.array(a)))
                idx_99 = int(cp.searchsorted(cdf, cp.array(1-a)))
            else:
                new_b_grid_gpu_1 = cp.linspace(new_b_grid_gpu[idx_01], new_b_grid_gpu[idx_99], 4000)
                new_res = float(new_b_grid_gpu_1[1] - new_b_grid_gpu_1[0])
                # We find which index in OLD grid is just left of each NEW point
                # searchsorted(old, new, side='right') - 1 gives the left neighbor index
                indices = cp.searchsorted(new_b_grid_gpu, new_b_grid_gpu_1, side='right') - 1
                indices = cp.clip(indices, 0, len(new_b_grid_gpu) - 1)
                new_posterior_gpu_1 = new_posterior_gpu[indices]  
                
                normalization = cp.trapz(new_posterior_gpu_1, new_b_grid_gpu_1)
                new_posterior_gpu = new_posterior_gpu_1/normalization
                new_b_grid_gpu = new_b_grid_gpu_1

                dB = new_b_grid_gpu[1:] - new_b_grid_gpu[:-1]
                pdf_mass = cp.zeros_like(new_posterior_gpu)
                pdf_mass[:-1] = new_posterior_gpu[:-1] * dB
                pdf_mass[-1] = new_posterior_gpu[-1] * dB[-1]
                cdf = cp.cumsum(pdf_mass)
                cdf /= cdf[-1] # Ensure it ends exactly at 1.0

                idx_01 = int(cp.searchsorted(cdf, cp.array(a)))
                idx_99 = int(cp.searchsorted(cdf, cp.array(1-a)))

        print(f"  [ZOOM] Res: {current_res} -> {new_res} | Grid Size: {len(new_b_grid_gpu)}|", end=" ")
        print(time.time() - to,"was the time taken to increase resolution.", end=" ")
        return new_posterior_gpu, new_b_grid_gpu, new_res
    
    # No Zoom
    return posterior_gpu, b_grid_gpu, current_res

def calculate_summary_stats(posterior, B_grid):
    # Mean
    mean = cp.trapz(B_grid*posterior, x = B_grid)

    # Mode
    mode_index = cp.argmax(posterior)
    mode = B_grid[mode_index]

     # Variance
    variance = cp.trapz(((B_grid - mean)**2) * posterior, x = B_grid)

    return float(mode), float(variance**0.5)

# %% [markdown]
# Can we get a GPU optimised interpolator?
#
# Also, note that given the bias values available to be applied y points of y axis grid of experimental data, those values are precisely our candidates.

# %%
def run_experiment_longitudinal_estimation(fixed_by_estimate = 0.0):
    print("Starting Adaptive Experiment...")
    #Load Data
    #t_sim, f_sim, sim_spline = load_simulation(SIM_FILES_Longitudinal_Estimation)
    t_sim, f_sim, by_sim, cube = load_simulation_cube(SIM_FILES_CONFIG_Y_Estimation)
    sim_spline = get_final_interpolator(t_sim, f_sim, by_sim, cube)
    t_exp, f_bias_axis, exp_matrix = load_experiment(EXP_FILES)
    f_bias_axis  += F_BIAS_OFFSET_NUISANCE
    
    #Align Time
    print("\nAligning t=0...")
    t_sim_0, _ = find_pulse_start(sim_spline((t_sim, 0, 0)), t_sim, 0.1)
    t_exp_0, __ = find_pulse_start(exp_matrix[:, 0], t_exp, 0.2)
    
    print(f"  > Sim Start: {t_sim_0:.4f}s")
    print(f"  > Exp Start: {t_exp_0:.4f}s")
    
    #Initialization of Grid
    b_grid_gpu = cp.arange(B_UNK_INITIAL_RANGE[0], B_UNK_INITIAL_RANGE[1], INITIAL_RESOLUTION)
    curr_res = INITIAL_RESOLUTION
    #Posterior (Uniform Density)
    #PDF = 1 / (Max - Min)
    pdf_val = 1.0 / (B_UNK_INITIAL_RANGE[1] - B_UNK_INITIAL_RANGE[0])
    posterior_gpu = cp.full_like(b_grid_gpu, pdf_val)
    
    #State
    curr_time = 5.0 #initial data is not nice, hence we are starting after about 5 seconds beyond which the data looks very nice
    curr_bias = 0.0
    
    history = {'time': [], 'est': [], 'stddev' : [], 'bias': [], 'res': [], 'posteriors': [], 'bgrids': [], 'expectedkl' : []}
    history['posteriors'].append(posterior_gpu.get())
    history['bgrids'].append(b_grid_gpu.get())
    
    start_wall = time.time()
    
    # 4. Loop
    while curr_time < MAX_TIME:
        
        # A. Measure 
        t_next = curr_time + T_STEP
        t_start_abs = t_exp_0 + curr_time
        t_end_abs = t_exp_0 + t_next
        
        # Find indices in Exp Matrix
        idx_start = np.searchsorted(t_exp, t_start_abs)
        idx_end = np.searchsorted(t_exp, t_end_abs)

        #FIXME: we can pass candidates array as the f_bias_axis, and that makes sense as far as this data is concerned, fix this after verifying KL divergence 
        bias_idx = (np.abs(f_bias_axis - curr_bias)).argmin()
        
        if idx_start >= idx_end: break # End of data
        
        y_obs = exp_matrix[idx_start:idx_end, bias_idx]
        t_chunk_exp = t_exp[idx_start:idx_end]
        
        #Posterior Update 
        # Map Exp Time -> Sim Time
        t_sim_eval = (t_chunk_exp - t_exp_0) + t_sim_0
          
        likelihood = calculate_likelihood_gpu(
            y_obs, t_sim_eval, curr_bias, fixed_by_estimate, b_grid_gpu, sim_spline, SIGMA_NOISE
        )
        
        posterior_gpu *= likelihood
        norm = cp.trapz(posterior_gpu, x = b_grid_gpu)
        posterior_gpu /= norm
        
        #Adaptive Zoom
        posterior_gpu, b_grid_gpu, curr_res = check_and_apply_zoom(
            posterior_gpu, b_grid_gpu, curr_res
        )
        
        #Record
        # MAP Estimate
        mode,stddev  = calculate_summary_stats(posterior_gpu,b_grid_gpu)
        
        history['time'].append(t_next)
        history['est'].append(mode)
        history['stddev'].append(stddev)
        history['bias'].append(curr_bias)
        history['res'].append(curr_res)
        history['posteriors'].append(posterior_gpu.get())
        history['bgrids'].append(b_grid_gpu.get())
        
        
        print("\n",f"T={t_next:.1f}s | Bias={curr_bias:.3f} | Est={mode:.5f} | Res={curr_res:.1e}", end=" ")
        
        #Adapt Control 
        t_fut_1 = t_next + t_sim_0
        t_fut_2 = t_next + T_STEP + t_sim_0 
        
        next_bias, expectedkl = calculate_kl_divergence_gpu(
            posterior_gpu, b_grid_gpu, fixed_by_estimate, sim_spline, 
            t_fut_1, t_fut_2, f_bias_axis, batch_size=131
        )
        
        history['expectedkl'].append(expectedkl.get())
        curr_bias = next_bias
        curr_time = t_next
        
    print("\n",f"Done in {time.time() - start_wall:.2f}s")
    return history

def run_experiment_y_estimation(fixed_bz_estimate = 0.0):
    print("...Starting Adaptive Experiment for Y Estimation...")
    t_sim, f_sim, by_sim, cube = load_simulation_cube(SIM_FILES_CONFIG_Y_Estimation)
    t_exp, f_bias_axis, exp_matrix = load_experiment(EXP_FILES)
    sim_interp = get_final_interpolator(t_sim, f_sim, by_sim, cube)
    t_sim_0, _ = find_pulse_start(sim_interp((t_sim, 0, 0)), t_sim, 0.1)
    t_exp_0, _ = find_pulse_start(exp_matrix[:, 0], t_exp, 0.2)

    b_grid_gpu = cp.arange(b_y_bounds[0], b_y_bounds[1], initial_res_by)
    curr_res = initial_res_by

    posterior_gpu = cp.ones_like(b_grid_gpu)
    posterior_gpu /= (cp.sum(posterior_gpu) * curr_res)

    curr_time = 5.0
    curr_bias_z = 0.0

    history = {'time': [], 'est': [], 'stddev' : [], 'bias': [], 'res': [], 'posteriors': [], 'bgrids': [], 'expectedkl' : []}
    history['posteriors'].append(posterior_gpu.get())
    history['bgrids'].append(b_grid_gpu.get())

    start_wall = time.time()
    
    while curr_time < MAX_TIME:
        t_next = curr_time + T_STEP
        t_abs_start = t_exp_0 + curr_time
        t_abs_end = t_exp_0 + t_next
        idx_start = np.searchsorted(t_exp, t_abs_start)
        idx_end = np.searchsorted(t_exp, t_abs_end)
        bias_idx = (np.abs(f_bias_axis - curr_bias_z)).argmin()

        if idx_start >= idx_end: break
        y_obs = exp_matrix[idx_start:idx_end, bias_idx]
        t_chunk_exp = t_exp[idx_start:idx_end]
        t_chunk_sim = (t_chunk_exp - t_exp_0) + t_sim_0

        by_grid_cpu = cp.asnumpy(b_grid_gpu)
        plt.plot(b_grid_gpu.get(), posterior_gpu.get())
        plt.show()

        likelihood = calculate_likelihood_by(
            y_obs, t_chunk_sim, curr_bias_z, by_grid_cpu, sim_interp, SIGMA_NOISE
        )
        
        posterior_gpu *= likelihood
        norm = cp.trapz(posterior_gpu, b_grid_gpu)
        posterior_gpu /= norm

        plt.plot(b_grid_gpu.get(), posterior_gpu.get())
        plt.show()

        posterior_gpu, b_grid_gpu, curr_res = check_and_apply_zoom_by(
            posterior_gpu, b_grid_gpu, curr_res
        )
        
        
        mode,stddev  = calculate_summary_stats(posterior_gpu,b_grid_gpu)
        
        history['time'].append(t_next)
        history['est'].append(mode)
        history['stddev'].append(stddev)
        history['bias'].append(curr_bias_z)
        history['res'].append(curr_res)
        history['posteriors'].append(posterior_gpu.get())
        history['bgrids'].append(b_grid_gpu.get())

        print(f"T={t_next:.1f} | BiasZ={curr_bias_z:.3f} | Est By={mode:.5f} | Std={stddev:.4f}")
        
        t_fut_1 = t_next + t_sim_0
        t_fut_2 = t_next + T_STEP + t_sim_0
        
        next_bias, expectedkl = calculate_kl_by(
            posterior_gpu, b_grid_gpu, sim_interp,
            t_fut_1, t_fut_2, f_bias_axis
        )

        history['expectedkl'].append(expectedkl.get())
        curr_bias_z = next_bias
        curr_time = t_next

    print("\n",f"Done in {time.time() - start_wall:.2f}s")
    return history

# %% [markdown]
# Goals:
# 1. heatmap of trajectory is required IG.

# %% [markdown]
# Check: Does the dataloader and pulse threshold detection work?

# %%
t_sim, f_sim, sim_spline = load_simulation(SIM_FILES_Longitudinal_Estimation)
t_exp, f_bias_axis, exp_matrix = load_experiment(EXP_FILES)
# Out:
# Loading Simulation from DataFiles_to_Dinesh_Pranav\Data_files\Simulation\Dataset_0\transHport_t_vs_Bz_delx_0.01_dely_0.1.csv...
# 0.9229183197021484 was the time taken to load sim data.
# Loading Experiment from DataFiles_to_Dinesh_Pranav\Data_files\Experiment\Probe_trans_Exp.csv...
# 0.04714202880859375 was the time taken to load exp data.

# %%
print(exp_matrix.shape)
# Out:
# (3119, 91)

# %%
print("Sim Data")
plot_heat_and_surface(t_sim, f_sim, sim_spline(t_sim,f_sim))
print("Exp Data")
plot_heat_and_surface(t_exp, f_bias_axis+F_BIAS_OFFSET_NUISANCE, exp_matrix)
# Out:
# Sim Data
# Exp Data

# %% [markdown]
# When does simulation signal turn on?

# %%
sim_trace_0 = sim_spline(t_sim, f_sim[45]).flatten()
print(sim_trace_0.shape)
t_sim_0, _ = find_pulse_start(sim_trace_0, t_sim, SIM_PULSE_THRESH)
print(t_sim_0)
plt.plot((t_sim-t_sim_0), sim_spline(t_sim, 0),marker ='.',ms=5, label="signal plot", linestyle ='None')
plt.show()
# Out:
# (32800,)
# 1.37099999999996

# %% [markdown]
# When does experiment signal turn on?

# %%
exp_trace_0 = exp_matrix[:,0].flatten()
print(exp_trace_0.shape)
a = 0
b = len(t_exp) - 1
t_exp_0, __ = find_pulse_start(exp_trace_0, t_exp, EXP_PULSE_THRESH)
print(t_exp_0)
plt.plot((t_exp-t_exp_0)[a:b], exp_matrix[a:b, 0], marker ='.',ms=4, label="signal plot", linestyle ='None')
plt.plot((t_sim-t_sim_0), sim_spline(t_sim, 0),marker ='.',ms=5, label="signal plot", linestyle ='None')
slope, intercept = np.polyfit((t_exp-t_exp_0)[a:b], exp_matrix[a:b, 0], 1)
line_x = np.array([min((t_exp-t_exp_0)[a:b]), max((t_exp-t_exp_0)[a:b])])
line_y = slope * line_x + intercept
plt.plot(line_x, line_y, color='red', label=f'Best Fit Line: y={slope:.2f}x + {intercept:.2f}')
plt.show()
# Out:
# (3119,)
# 2.44000000000004

# %%
print("Sim Data after alignment of axis")
plot_heat_and_surface((t_sim[_:] -t_sim_0), f_sim, sim_spline(t_sim[_:],f_sim))
print("Exp Data after alignment of axis")
plot_heat_and_surface((t_exp[__:]-t_exp_0), f_bias_axis+F_BIAS_OFFSET_NUISANCE, exp_matrix[__:,])
print("Difference Data after alignment of axis")
plot_heat_and_surface(t_exp, f_bias_axis+F_BIAS_OFFSET_NUISANCE, sim_spline(t_exp,f_bias_axis+F_BIAS_OFFSET_NUISANCE) - exp_matrix)
# Out:
# Sim Data after alignment of axis
# Exp Data after alignment of axis
# Difference Data after alignment of axis

# %%
print("Effective number of experiment time points we have are", len(t_exp[__:]))
print((t_exp[__:]-t_exp_0)[-1])
print(exp_matrix.shape)
print(2866//91)
# Out:
# Effective number of experiment time points we have are 2866
# 27.60999999999996
# (3119, 91)
# 31

# %%
MAX_TIME = 30
results_longitudinal_estimation = run_experiment_longitudinal_estimation(fixed_by_estimate)
# Out:
# Starting Adaptive Experiment...
# ...Loading Simulation Cube Data...
#   > Axes Loaded: Time[32800], Freq[91], By[12]
#   > Cube Built. Final Shape: (32800, 91, 12)
# Time taken to load sim data: 3.1309285163879395
# ...Building Final Interpolator...
# Time taken to load Interpolator: 0.18751835823059082
# Loading Experiment from DataFiles_to_Dinesh_Pranav\Data_files\Experiment\Probe_trans_Exp.csv...
# 0.05026531219482422 was the time taken to load exp data.
#
# Aligning t=0...
#   > Sim Start: 1.3710s
#   > Exp Start: 2.4400s
# 0.09757280349731445 was the time taken to compute the likelihood.| 1999
#  T=5.2s | Bias=0.000 | Est=-0.07100 | Res=1.0e-03 (91, 2000)
# 0.5244894027709961 was the time taken to compute the KL optimisation. 0.08607602119445801 was the time taken to compute the likelihood.| 1999
#  T=5.4s | Bias=-0.107 | Est=-1.00000 | Res=1.0e-03 (91, 2000)
# 0.4407005310058594 was the time taken to compute the KL optimisation. 0.1011042594909668 was the time taken to compute the likelihood.| 1959
#  T=5.6s | Bias=1.018 | Est=-0.95100 | Res=1.0e-03 (91, 2000)
# 0.44847631454467773 was the time taken to compute the KL optimisation. 0.09431743621826172 was the time taken to compute the likelihood.| 199   [ZOOM] Triggered! Mass concentrated in 199 points.|   [ZOOM] Res: 0.001000 -> 0.000400 | Grid Size: 2411| 0.0017282962799072266 was the time taken to increase resolution.
#  T=5.8s | Bias=0.911 | Est=0.99900 | Res=4.0e-04 (91, 2411)
# 0.5552361011505127 was the time taken to compute the KL optimisation. 0.12645721435546875 was the time taken to compute the likelihood.| 60   [ZOOM] Triggered! Mass concentrated in 60 points.|   [ZOOM] Triggered! Mass concentrated in 163 points.|   [ZOOM] Triggered! Mass concentrated in 476 points.|   [ZOOM] Res: 0.000400 -> 0.000026 | Grid Size: 3614| 0.0050084590911865234 was the time taken to increase resolution.
#  T=6.0s | Bias=-1.018 | Est=0.94800 | Res=2.6e-05 (91, 3614)
# 0.8580591678619385 was the time taken to compute the KL optimisation. 0.16866493225097656 was the time taken to compute the likelihood.| 1031
#  T=6.2s | Bias=-0.911 | Est=0.05700 | Res=2.6e-05 (91, 3614)
# 0.8726527690887451 was the time taken to compute the KL optimisation. 0.20029401779174805 was the time taken to compute the likelihood.| 1027
#  T=6.4s | Bias=-0.107 | Est=0.05200 | Res=2.6e-05 (91, 3614)
# 0.8934192657470703 was the time taken to compute the KL optimisation. 0.18622565269470215 was the time taken to compute the likelihood.| 9   [ZOOM] Triggered! Mass concentrated in 9 points.|   [ZOOM] Res: 0.000026 -> 0.000010 | Grid Size: 4492| 0.0020799636840820312 was the time taken to increase resolution.
#  T=6.6s | Bias=-2.037 | Est=0.05200 | Res=1.0e-05 (91, 4492)
# 1.1331148147583008 was the time taken to compute the KL optimisation. 0.2600381374359131 was the time taken to compute the likelihood.| 273
#  T=6.8s | Bias=0.000 | Est=0.05699 | Res=1.0e-05 (91, 4492)
# 1.1532163619995117 was the time taken to compute the KL optimisation. 0.24033594131469727 was the time taken to compute the likelihood.| 529
#  T=7.0s | Bias=-0.107 | Est=0.05699 | Res=1.0e-05 (91, 4492)
# 1.1808223724365234 was the time taken to compute the KL optimisation. 0.2600536346435547 was the time taken to compute the likelihood.| 3319
#  T=7.2s | Bias=-0.107 | Est=0.05300 | Res=1.0e-05 (91, 4492)
# 1.2065260410308838 was the time taken to compute the KL optimisation. 0.26317811012268066 was the time taken to compute the likelihood.| 66
#  T=7.4s | Bias=0.000 | Est=0.96500 | Res=1.0e-05 (91, 4492)
# 1.2303776741027832 was the time taken to compute the KL optimisation. 0.2683851718902588 was the time taken to compute the likelihood.| 2859
#  T=7.6s | Bias=-1.018 | Est=0.95784 | Res=1.0e-05 (91, 4492)
# 1.2538349628448486 was the time taken to compute the KL optimisation. 0.26185107231140137 was the time taken to compute the likelihood.| 2560
#  T=7.8s | Bias=0.161 | Est=0.95784 | Res=1.0e-05 (91, 4492)
# 1.2839508056640625 was the time taken to compute the KL optimisation. 0.2827434539794922 was the time taken to compute the likelihood.| 401
#  T=8.0s | Bias=-0.911 | Est=0.05699 | Res=1.0e-05 (91, 4492)
# 1.3076143264770508 was the time taken to compute the KL optimisation. 0.289379358291626 was the time taken to compute the likelihood.| 516
#  T=8.2s | Bias=-0.107 | Est=0.05400 | Res=1.0e-05 (91, 4492)
# 1.338597059249878 was the time taken to compute the KL optimisation. 0.29302310943603516 was the time taken to compute the likelihood.| 596
#  T=8.4s | Bias=-0.107 | Est=0.05400 | Res=1.0e-05 (91, 4492)
# 1.365856409072876 was the time taken to compute the KL optimisation. 0.2882668972015381 was the time taken to compute the likelihood.| 627
#  T=8.6s | Bias=-0.107 | Est=0.05400 | Res=1.0e-05 (91, 4492)
# 1.4044628143310547 was the time taken to compute the KL optimisation. 0.3130815029144287 was the time taken to compute the likelihood.| 613
#  T=8.8s | Bias=-0.107 | Est=0.05300 | Res=1.0e-05 (91, 4492)
# 1.4175677299499512 was the time taken to compute the KL optimisation. 0.31246161460876465 was the time taken to compute the likelihood.| 493
#  T=9.0s | Bias=0.000 | Est=0.05400 | Res=1.0e-05 (91, 4492)
# 1.4578776359558105 was the time taken to compute the KL optimisation. 0.32772159576416016 was the time taken to compute the likelihood.| 493
#  T=9.2s | Bias=-0.107 | Est=0.05400 | Res=1.0e-05 (91, 4492)
# 1.4971890449523926 was the time taken to compute the KL optimisation. 0.33090972900390625 was the time taken to compute the likelihood.| 493
#  T=9.4s | Bias=-0.107 | Est=0.05400 | Res=1.0e-05 (91, 4492)
# 1.5229899883270264 was the time taken to compute the KL optimisation. 0.30406904220581055 was the time taken to compute the likelihood.| 492
#  T=9.6s | Bias=-0.107 | Est=0.05400 | Res=1.0e-05 (91, 4492)
# 1.5364410877227783 was the time taken to compute the KL optimisation. 0.35888671875 was the time taken to compute the likelihood.| 492
#  T=9.8s | Bias=-0.107 | Est=0.05400 | Res=1.0e-05 (91, 4492)
# 1.559737205505371 was the time taken to compute the KL optimisation. 0.3285837173461914 was the time taken to compute the likelihood.| 470
#  T=10.0s | Bias=-0.107 | Est=0.05400 | Res=1.0e-05 (91, 4492)
# 1.589930534362793 was the time taken to compute the KL optimisation. 0.3705265522003174 was the time taken to compute the likelihood.| 447
#  T=10.2s | Bias=-0.107 | Est=0.05400 | Res=1.0e-05 (91, 4492)
# 1.599823236465454 was the time taken to compute the KL optimisation. 0.3233954906463623 was the time taken to compute the likelihood.| 432
#  T=10.4s | Bias=-0.107 | Est=0.05400 | Res=1.0e-05 (91, 4492)
# 1.6334254741668701 was the time taken to compute the KL optimisation. 0.3801090717315674 was the time taken to compute the likelihood.| 416
#  T=10.6s | Bias=-0.107 | Est=0.05500 | Res=1.0e-05 (91, 4492)
# 1.6551141738891602 was the time taken to compute the KL optimisation. 0.348099946975708 was the time taken to compute the likelihood.| 400   [ZOOM] Triggered! Mass concentrated in 400 points.|   [ZOOM] Res: 0.000010 -> 0.000004 | Grid Size: 5367| 0.004064321517944336 was the time taken to increase resolution.
#  T=10.8s | Bias=-0.107 | Est=0.05500 | Res=4.1e-06 (91, 5367)
# 2.0250699520111084 was the time taken to compute the KL optimisation. 0.4710402488708496 was the time taken to compute the likelihood.| 1275
#  T=11.0s | Bias=-0.107 | Est=0.05500 | Res=4.1e-06 (91, 5367)
# 2.0308010578155518 was the time taken to compute the KL optimisation. 0.4098484516143799 was the time taken to compute the likelihood.| 1275
#  T=11.2s | Bias=-0.107 | Est=0.05500 | Res=4.1e-06 (91, 5367)
# 2.0853934288024902 was the time taken to compute the KL optimisation. 0.4852008819580078 was the time taken to compute the likelihood.| 1259
#  T=11.4s | Bias=-0.107 | Est=0.05500 | Res=4.1e-06 (91, 5367)
# 2.079819679260254 was the time taken to compute the KL optimisation. 0.46404480934143066 was the time taken to compute the likelihood.| 1222
#  T=11.6s | Bias=-0.107 | Est=0.05500 | Res=4.1e-06 (91, 5367)
# 2.085885524749756 was the time taken to compute the KL optimisation. 0.46515870094299316 was the time taken to compute the likelihood.| 1143
#  T=11.8s | Bias=-0.107 | Est=0.05500 | Res=4.1e-06 (91, 5367)
# 2.1111974716186523 was the time taken to compute the KL optimisation. 0.4499642848968506 was the time taken to compute the likelihood.| 1097
#  T=12.0s | Bias=-0.107 | Est=0.05555 | Res=4.1e-06 (91, 5367)
# 2.1680264472961426 was the time taken to compute the KL optimisation. 0.47967052459716797 was the time taken to compute the likelihood.| 1069
#  T=12.2s | Bias=-0.107 | Est=0.05555 | Res=4.1e-06 (91, 5367)
# 2.2076575756073 was the time taken to compute the KL optimisation. 0.488800048828125 was the time taken to compute the likelihood.| 1024
#  T=12.4s | Bias=-0.107 | Est=0.05559 | Res=4.1e-06 (91, 5367)
# 2.2081971168518066 was the time taken to compute the KL optimisation. 0.49370408058166504 was the time taken to compute the likelihood.| 966
#  T=12.6s | Bias=-0.107 | Est=0.05567 | Res=4.1e-06 (91, 5367)
# 2.2560436725616455 was the time taken to compute the KL optimisation. 0.47969841957092285 was the time taken to compute the likelihood.| 941
#  T=12.8s | Bias=-0.107 | Est=0.05571 | Res=4.1e-06 (91, 5367)
# 2.294248342514038 was the time taken to compute the KL optimisation. 0.5040271282196045 was the time taken to compute the likelihood.| 941
#  T=13.0s | Bias=-0.107 | Est=0.05573 | Res=4.1e-06 (91, 5367)
# 2.28169322013855 was the time taken to compute the KL optimisation. 0.5125365257263184 was the time taken to compute the likelihood.| 882
#  T=13.2s | Bias=-0.107 | Est=0.05582 | Res=4.1e-06 (91, 5367)
# 2.3471834659576416 was the time taken to compute the KL optimisation. 0.5208947658538818 was the time taken to compute the likelihood.| 816
#  T=13.4s | Bias=-0.107 | Est=0.05699 | Res=4.1e-06 (91, 5367)
# 2.3824832439422607 was the time taken to compute the KL optimisation. 0.5044863224029541 was the time taken to compute the likelihood.| 751
#  T=13.6s | Bias=-0.107 | Est=0.05699 | Res=4.1e-06 (91, 5367)
# 2.38424015045166 was the time taken to compute the KL optimisation. 0.5381767749786377 was the time taken to compute the likelihood.| 693
#  T=13.8s | Bias=-0.107 | Est=0.05699 | Res=4.1e-06 (91, 5367)
# 2.4255130290985107 was the time taken to compute the KL optimisation. 0.5452384948730469 was the time taken to compute the likelihood.| 628
#  T=14.0s | Bias=-0.107 | Est=0.05699 | Res=4.1e-06 (91, 5367)
# 2.499648332595825 was the time taken to compute the KL optimisation. 0.5322515964508057 was the time taken to compute the likelihood.| 573
#  T=14.2s | Bias=-0.107 | Est=0.05699 | Res=4.1e-06 (91, 5367)
# 2.5338315963745117 was the time taken to compute the KL optimisation. 0.56461501121521 was the time taken to compute the likelihood.| 527
#  T=14.4s | Bias=-0.107 | Est=0.05699 | Res=4.1e-06 (91, 5367)
# 2.53904390335083 was the time taken to compute the KL optimisation. 0.5401158332824707 was the time taken to compute the likelihood.| 470   [ZOOM] Triggered! Mass concentrated in 470 points.|   [ZOOM] Res: 0.000004 -> 0.000002 | Grid Size: 6247| 0.0025076866149902344 was the time taken to increase resolution.
#  T=14.6s | Bias=-0.107 | Est=0.05699 | Res=1.6e-06 (91, 6247)
# 2.994328022003174 was the time taken to compute the KL optimisation. 0.698991060256958 was the time taken to compute the likelihood.| 1349
#  T=14.8s | Bias=-0.107 | Est=0.05699 | Res=1.6e-06 (91, 6247)
# 3.028010845184326 was the time taken to compute the KL optimisation. 0.6537573337554932 was the time taken to compute the likelihood.| 1349
#  T=15.0s | Bias=-0.107 | Est=0.05699 | Res=1.6e-06 (91, 6247)
# 3.075817108154297 was the time taken to compute the KL optimisation. 0.6866686344146729 was the time taken to compute the likelihood.| 1345
#  T=15.2s | Bias=-0.107 | Est=0.05699 | Res=1.6e-06 (91, 6247)
# 3.0998597145080566 was the time taken to compute the KL optimisation. 0.6582727432250977 was the time taken to compute the likelihood.| 1248
#  T=15.4s | Bias=-0.107 | Est=0.05699 | Res=1.6e-06 (91, 6247)
# 3.077934741973877 was the time taken to compute the KL optimisation. 0.7188339233398438 was the time taken to compute the likelihood.| 962
#  T=15.6s | Bias=-0.107 | Est=0.05699 | Res=1.6e-06 (91, 6247)
# 3.097062349319458 was the time taken to compute the KL optimisation. 0.7021853923797607 was the time taken to compute the likelihood.| 739
#  T=15.8s | Bias=-0.107 | Est=0.05699 | Res=1.6e-06 (91, 6247)
# 3.150057554244995 was the time taken to compute the KL optimisation. 0.6687419414520264 was the time taken to compute the likelihood.| 617
#  T=16.0s | Bias=-0.107 | Est=0.05699 | Res=1.6e-06 (91, 6247)
# 3.164630651473999 was the time taken to compute the KL optimisation. 0.7157142162322998 was the time taken to compute the likelihood.| 559
#  T=16.2s | Bias=-0.107 | Est=0.05699 | Res=1.6e-06 (91, 6247)
# 3.2297585010528564 was the time taken to compute the KL optimisation. 0.7214150428771973 was the time taken to compute the likelihood.| 503
#  T=16.4s | Bias=-0.107 | Est=0.05699 | Res=1.6e-06 (91, 6247)
# 3.249755859375 was the time taken to compute the KL optimisation. 0.7251007556915283 was the time taken to compute the likelihood.| 446
#  T=16.6s | Bias=-0.107 | Est=0.05699 | Res=1.6e-06 (91, 6247)
# 3.283433198928833 was the time taken to compute the KL optimisation. 0.7375085353851318 was the time taken to compute the likelihood.| 397
#  T=16.8s | Bias=-0.107 | Est=0.05699 | Res=1.6e-06 (91, 6247)
# 3.310077428817749 was the time taken to compute the KL optimisation. 0.7029507160186768 was the time taken to compute the likelihood.| 311
#  T=17.0s | Bias=-0.107 | Est=0.05699 | Res=1.6e-06 (91, 6247)
# 3.42936110496521 was the time taken to compute the KL optimisation. 0.7744200229644775 was the time taken to compute the likelihood.| 199
#  T=17.2s | Bias=-0.107 | Est=0.05800 | Res=1.6e-06 (91, 6247)
# 3.461697816848755 was the time taken to compute the KL optimisation. 0.772418737411499 was the time taken to compute the likelihood.| 93
#  T=17.4s | Bias=-0.107 | Est=0.05900 | Res=1.6e-06 (91, 6247)
# 3.5062248706817627 was the time taken to compute the KL optimisation. 0.7875192165374756 was the time taken to compute the likelihood.| 2   [ZOOM] Triggered! Mass concentrated in 2 points.|   [ZOOM] Res: 0.000002 -> 0.000001 | Grid Size: 9298| 0.002001047134399414 was the time taken to increase resolution.
#  T=17.6s | Bias=-0.107 | Est=0.05900 | Res=6.6e-07 (91, 9298)
# 5.4085235595703125 was the time taken to compute the KL optimisation. 1.1304197311401367 was the time taken to compute the likelihood.| 3053
#  T=17.8s | Bias=-0.107 | Est=0.05900 | Res=6.6e-07 (91, 9298)
# 5.346032619476318 was the time taken to compute the KL optimisation. 1.18434739112854 was the time taken to compute the likelihood.| 3053
#  T=18.0s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 5.360320329666138 was the time taken to compute the KL optimisation. 1.1763010025024414 was the time taken to compute the likelihood.| 2545
#  T=18.2s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 5.357098817825317 was the time taken to compute the KL optimisation. 1.1966924667358398 was the time taken to compute the likelihood.| 2010
#  T=18.4s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 5.437966585159302 was the time taken to compute the KL optimisation. 1.155318260192871 was the time taken to compute the likelihood.| 1691
#  T=18.6s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 5.365096092224121 was the time taken to compute the KL optimisation. 1.163266897201538 was the time taken to compute the likelihood.| 1474
#  T=18.8s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 5.521787166595459 was the time taken to compute the KL optimisation. 1.277421236038208 was the time taken to compute the likelihood.| 1172
#  T=19.0s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 5.702280521392822 was the time taken to compute the KL optimisation. 1.199228286743164 was the time taken to compute the likelihood.| 1030
#  T=19.2s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 5.781027317047119 was the time taken to compute the KL optimisation. 1.2601327896118164 was the time taken to compute the likelihood.| 953
#  T=19.4s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 5.678809881210327 was the time taken to compute the KL optimisation. 1.2177958488464355 was the time taken to compute the likelihood.| 881
#  T=19.6s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 5.854725122451782 was the time taken to compute the KL optimisation. 1.3460187911987305 was the time taken to compute the likelihood.| 798
#  T=19.8s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 5.743321180343628 was the time taken to compute the KL optimisation. 1.219360589981079 was the time taken to compute the likelihood.| 738
#  T=20.0s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 5.834677219390869 was the time taken to compute the KL optimisation. 1.2385597229003906 was the time taken to compute the likelihood.| 696
#  T=20.2s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 5.769632816314697 was the time taken to compute the KL optimisation. 1.3656039237976074 was the time taken to compute the likelihood.| 659
#  T=20.4s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 5.898475646972656 was the time taken to compute the KL optimisation. 1.2475476264953613 was the time taken to compute the likelihood.| 621
#  T=20.6s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 5.912034273147583 was the time taken to compute the KL optimisation. 1.4157531261444092 was the time taken to compute the likelihood.| 588
#  T=20.8s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 6.170173406600952 was the time taken to compute the KL optimisation. 1.2308847904205322 was the time taken to compute the likelihood.| 563
#  T=21.0s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 6.189133167266846 was the time taken to compute the KL optimisation. 1.4418447017669678 was the time taken to compute the likelihood.| 516
#  T=21.2s | Bias=-0.107 | Est=0.06000 | Res=6.6e-07 (91, 9298)
# 6.1918556690216064 was the time taken to compute the KL optimisation. 1.322218894958496 was the time taken to compute the likelihood.| 415
#  T=21.4s | Bias=-0.107 | Est=0.06100 | Res=6.6e-07 (91, 9298)
# 6.241040945053101 was the time taken to compute the KL optimisation. 1.4581565856933594 was the time taken to compute the likelihood.| 314
#  T=21.6s | Bias=-0.107 | Est=0.06100 | Res=6.6e-07 (91, 9298)
# 6.260242938995361 was the time taken to compute the KL optimisation. 1.2645628452301025 was the time taken to compute the likelihood.| 251
#  T=21.8s | Bias=-0.107 | Est=0.06100 | Res=6.6e-07 (91, 9298)
# 6.23459005355835 was the time taken to compute the KL optimisation. 1.4801115989685059 was the time taken to compute the likelihood.| 177
#  T=22.0s | Bias=-0.107 | Est=0.06100 | Res=6.6e-07 (91, 9298)
# 6.488827705383301 was the time taken to compute the KL optimisation. 1.3530669212341309 was the time taken to compute the likelihood.| 110
#  T=22.2s | Bias=-0.107 | Est=0.06100 | Res=6.6e-07 (91, 9298)
# 6.44848370552063 was the time taken to compute the KL optimisation. 1.4962732791900635 was the time taken to compute the likelihood.| 37
#  T=22.4s | Bias=-0.107 | Est=0.06100 | Res=6.6e-07 (91, 9298)
# 6.496615886688232 was the time taken to compute the KL optimisation. 1.3053596019744873 was the time taken to compute the likelihood.| 1   [ZOOM] Triggered! Mass concentrated in 1 points.|   [ZOOM] Res: 0.000001 -> 0.000000 | Grid Size: 13112| 0.0030007362365722656 was the time taken to increase resolution.
#  T=22.6s | Bias=-0.107 | Est=0.06100 | Res=2.6e-07 (91, 13112)
# 9.382529020309448 was the time taken to compute the KL optimisation. 2.1584362983703613 was the time taken to compute the likelihood.| 3815
#  T=22.8s | Bias=-0.107 | Est=0.06100 | Res=2.6e-07 (91, 13112)
# 9.433513641357422 was the time taken to compute the KL optimisation. 1.9515964984893799 was the time taken to compute the likelihood.| 3815
#  T=23.0s | Bias=-0.107 | Est=0.06100 | Res=2.6e-07 (91, 13112)
# 9.262096881866455 was the time taken to compute the KL optimisation. 2.0627968311309814 was the time taken to compute the likelihood.| 3815
#  T=23.2s | Bias=-0.107 | Est=0.06200 | Res=2.6e-07 (91, 13112)
# 9.351790428161621 was the time taken to compute the KL optimisation. 1.9961328506469727 was the time taken to compute the likelihood.| 3815
#  T=23.4s | Bias=-0.107 | Est=0.06200 | Res=2.6e-07 (91, 13112)
# 9.566848754882812 was the time taken to compute the KL optimisation. 2.1365416049957275 was the time taken to compute the likelihood.| 3815
#  T=23.6s | Bias=-0.107 | Est=0.06200 | Res=2.6e-07 (91, 13112)
# 9.846945524215698 was the time taken to compute the KL optimisation. 2.1423163414001465 was the time taken to compute the likelihood.| 3815
#  T=23.8s | Bias=-0.107 | Est=0.06200 | Res=2.6e-07 (91, 13112)
# 9.883918523788452 was the time taken to compute the KL optimisation. 2.1353561878204346 was the time taken to compute the likelihood.| 3815
#  T=24.0s | Bias=-0.107 | Est=0.06200 | Res=2.6e-07 (91, 13112)
# 9.85185956954956 was the time taken to compute the KL optimisation. 2.037595510482788 was the time taken to compute the likelihood.| 3587
#  T=24.2s | Bias=-0.107 | Est=0.06200 | Res=2.6e-07 (91, 13112)
# 9.964381694793701 was the time taken to compute the KL optimisation. 2.1873269081115723 was the time taken to compute the likelihood.| 2795
#  T=24.4s | Bias=-0.107 | Est=0.06200 | Res=2.6e-07 (91, 13112)
# 9.976709127426147 was the time taken to compute the KL optimisation. 2.3036715984344482 was the time taken to compute the likelihood.| 2384
#  T=24.6s | Bias=-0.107 | Est=0.06200 | Res=2.6e-07 (91, 13112)
# 10.091301679611206 was the time taken to compute the KL optimisation. 2.108394145965576 was the time taken to compute the likelihood.| 2062
#  T=24.8s | Bias=-0.107 | Est=0.06200 | Res=2.6e-07 (91, 13112)
# 10.107578992843628 was the time taken to compute the KL optimisation. 2.29695725440979 was the time taken to compute the likelihood.| 1777
#  T=25.0s | Bias=-0.107 | Est=0.06200 | Res=2.6e-07 (91, 13112)
# 9.902982473373413 was the time taken to compute the KL optimisation. 1.9961235523223877 was the time taken to compute the likelihood.| 1601
#  T=25.2s | Bias=-0.107 | Est=0.06200 | Res=2.6e-07 (91, 13112)
# 10.03564739227295 was the time taken to compute the KL optimisation. 2.3269219398498535 was the time taken to compute the likelihood.| 1470
#  T=25.4s | Bias=-0.107 | Est=0.06200 | Res=2.6e-07 (91, 13112)
# 10.320916652679443 was the time taken to compute the KL optimisation. 2.1809988021850586 was the time taken to compute the likelihood.| 1316
#  T=25.6s | Bias=-0.107 | Est=0.06200 | Res=2.6e-07 (91, 13112)
# 10.5442636013031 was the time taken to compute the KL optimisation. 2.449707269668579 was the time taken to compute the likelihood.| 982
#  T=25.8s | Bias=-0.107 | Est=0.06300 | Res=2.6e-07 (91, 13112)
# 10.461663722991943 was the time taken to compute the KL optimisation. 2.097132921218872 was the time taken to compute the likelihood.| 743
#  T=26.0s | Bias=-0.107 | Est=0.06300 | Res=2.6e-07 (91, 13112)
# 10.611474514007568 was the time taken to compute the KL optimisation. 2.4258058071136475 was the time taken to compute the likelihood.| 478
#  T=26.2s | Bias=-0.107 | Est=0.06300 | Res=2.6e-07 (91, 13112)
# 10.563234806060791 was the time taken to compute the KL optimisation. 2.231823682785034 was the time taken to compute the likelihood.| 267
#  T=26.4s | Bias=-0.107 | Est=0.06300 | Res=2.6e-07 (91, 13112)
# 10.727785348892212 was the time taken to compute the KL optimisation. 2.4748728275299072 was the time taken to compute the likelihood.| 28
#  T=26.6s | Bias=-0.107 | Est=0.06300 | Res=2.6e-07 (91, 13112)
# 10.918367385864258 was the time taken to compute the KL optimisation. 2.1684303283691406 was the time taken to compute the likelihood.| 1   [ZOOM] Triggered! Mass concentrated in 1 points.|   [ZOOM] Res: 0.000000 -> 0.000000 | Grid Size: 4000| 0.2235851287841797 was the time taken to increase resolution.
#  T=26.8s | Bias=-0.107 | Est=0.06300 | Res=2.5e-07 (91, 4000)
# 3.260679244995117 was the time taken to compute the KL optimisation. 0.7540380954742432 was the time taken to compute the likelihood.| 3997
#  T=27.0s | Bias=-0.107 | Est=0.06300 | Res=2.5e-07 (91, 4000)
# 3.1909544467926025 was the time taken to compute the KL optimisation. 0.6914005279541016 was the time taken to compute the likelihood.| 3856
#  T=27.2s | Bias=-0.107 | Est=0.06300 | Res=2.5e-07 (91, 4000)
# 3.222327470779419 was the time taken to compute the KL optimisation. 0.764592170715332 was the time taken to compute the likelihood.| 2946
#  T=27.4s | Bias=-0.107 | Est=0.06300 | Res=2.5e-07 (91, 4000)
# 3.269108533859253 was the time taken to compute the KL optimisation. 0.6673741340637207 was the time taken to compute the likelihood.| 2284
#  T=27.6s | Bias=-0.107 | Est=0.06300 | Res=2.5e-07 (91, 4000)
# 3.2688028812408447 was the time taken to compute the KL optimisation. 0.06947779655456543 was the time taken to compute the likelihood.| 2252
#  T=27.8s | Bias=-0.107 | Est=0.06300 | Res=2.5e-07 (91, 4000)
# 3.297391176223755 was the time taken to compute the KL optimisation.
#  Done in 611.21s

# %%
t,est,stddev,bias,res,posteriors,bgrid,expectedkl = results_longitudinal_estimation['time'], results_longitudinal_estimation['est'],results_longitudinal_estimation['stddev'], results_longitudinal_estimation['bias'], results_longitudinal_estimation['res'], results_longitudinal_estimation['posteriors'], results_longitudinal_estimation['bgrids'], results_longitudinal_estimation['expectedkl']
result_longitudinal_estimation = {
    'time':np.array(t), 
    'est':np.array(est), 
    'stddev':np.array(stddev), 
    'bias':np.array(bias), 
    'res':np.array(res), 
    'posteriors':np.array(posteriors, dtype=object), 
    'bgrids':np.array(bgrid, dtype=object), 
    'expectedkl':np.array(expectedkl, dtype=object)
}
np.savez_compressed(f"Tests/Actual/CW/Test_{Test}/Test_{Test}_results_longitudinal_estimation.npz", **result_longitudinal_estimation)
print("Results data saved successfully.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 12
#       1 t,est,stddev,bias,res,posteriors,bgrid,expectedkl = results_longitudinal_estimation['time'], results_longitudinal_estimation['est'],results_longitudinal_estimation['stddev'], results_longitudinal_estimation['bias'], results_longitudinal_estimation['res'], results_longitudinal_estimation['posteriors'], results_longitudinal_estimation['bgrids'], results_longitudinal_estimation['expectedkl']
#       2 result_longitudinal_estimation = {
#       3     'time':np.array(t),
#       4     'est':np.array(est),
#    (...)     10     'expectedkl':np.array(expectedkl, dtype=object)
#      11 }
# ---> 12 np.savez_compressed(f"Tests/Actual/CW/Test_{Test}/Test_{Test}_results_longitudinal_estimation.npz", **result_longitudinal_estimation)
#      13 print("Results data saved successfully.")
#
# File c:\Users\Admin\.conda\envs\bayesian_nmor\Lib\site-packages\numpy\lib\_npyio_impl.py:766, in savez_compressed(file, allow_pickle, *args, **kwds)
#     694 @array_function_dispatch(_savez_compressed_dispatcher)
#     695 def savez_compressed(file, *args, allow_pickle=True, **kwds):
#     696     """
#     697     Save several arrays into a single file in compressed ``.npz`` format.
#     698
#    (...)    764
#     765     """
# --> 766     _savez(file, args, kwds, True, allow_pickle=allow_pickle)
#
# File c:\Users\Admin\.conda\envs\bayesian_nmor\Lib\site-packages\numpy\lib\_npyio_impl.py:792, in _savez(file, args, kwds, compress, allow_pickle, pickle_kwargs)
#     789 else:
#     790     compression = zipfile.ZIP_STORED
# --> 792 zipf = zipfile_factory(file, mode="w", compression=compression)
#     793 try:
#     794     for key, val in namedict.items():
#
# File c:\Users\Admin\.conda\envs\bayesian_nmor\Lib\site-packages\numpy\lib\_npyio_impl.py:112, in zipfile_factory(file, *args, **kwargs)
#     110 import zipfile
#     111 kwargs['allowZip64'] = True
# --> 112 return zipfile.ZipFile(file, *args, **kwargs)
#
# File c:\Users\Admin\.conda\envs\bayesian_nmor\Lib\zipfile\__init__.py:1352, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1350 while True:
#    1351     try:
# -> 1352         self.fp = io.open(file, filemode)
#    1353     except OSError:
#    1354         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Tests/Actual/CW/Test_8/Test_8_results_longitudinal_estimation.npz'

# %%
Test = 6
result_longitudinal_estimation = np.load(f"Tests/Actual/CW/Test_{Test}/Test_{Test}_results.npz", allow_pickle=True)
t,est,stddev,bias,res,posteriors,bgrid,expectedkl = result_longitudinal_estimation['time'], result_longitudinal_estimation['est'],result_longitudinal_estimation['stddev'], result_longitudinal_estimation['bias'], result_longitudinal_estimation['res'], result_longitudinal_estimation['posteriors'], result_longitudinal_estimation['bgrids'], result_longitudinal_estimation['expectedkl']
print("Results data loaded successfully.")
exp_trace_0 = exp_matrix[:,0].flatten()
print(exp_trace_0.shape)
t_exp_0, __ = find_pulse_start(exp_trace_0, t_exp, EXP_PULSE_THRESH)
plot_heat_and_surface((t_exp[__:]-t_exp_0), f_bias_axis, exp_matrix[__:,], trajectory_mode=True,traj_bias = bias, estimation_mode = 'longitudinal')
# Out:
# Results data loaded successfully.
# (3119,)

# %%
final_posterior = posteriors[-1]
print(est[-1], stddev[-1])
area = np.trapezoid(final_posterior, x = bgrid[-1])
print(f"Final posterior area (should be ~1): {area:.6f}")

plt.figure(figsize=(6, 4))
plt.plot(bgrid[-1], final_posterior, label="final posterior")
plt.xlabel("B")
plt.ylabel("Density")
plt.title("Posterior after adaptive experiment")
plt.legend()
plt.axvline(
    bgrid[-1][np.argmax(final_posterior)],
    color="green",
    linestyle="--",
    label="MAP Estimate",
)
plt.show()
# Out:
# 0.08100800000000002 0.0001575504790686455
# Final posterior area (should be ~1): 1.000000

# %% [markdown]
# Gif: Posterior

# %%
# Setup figure
fig, ax = plt.subplots(figsize=(8, 6))
line, = ax.plot([], [], lw=2)
ax.set_xlabel("Magnetic Field B")
ax.set_ylabel("Posterior Probability")
ax.grid(True)

# Initialization function
def init():
    line.set_data([], [])
    return line,

# Animation update function
def update(frame):
    # Assuming bgrid and posteriors are lists/arrays of length 90
    x = bgrid[frame]
    y = posteriors[frame]
    
    # Update data
    line.set_data(x, y)
    
    # Rescale axes dynamically to fit the new zoomed/peaked distribution
    ax.set_xlim(x.min(), x.max())
    ax.set_ylim(0, y.max() * 1.1)
    ax.set_title(f"Posterior Step {frame}")
    return line,

# Create animation (interval in milliseconds)
anim = FuncAnimation(fig, update, frames=len(posteriors), 
                     init_func=init, blit=False, interval=100)

# Option 2: Save as GIF (No external dependencies usually)
anim.save(f'Tests/Actual/CW/Test_{Test}/posterior_evolution.gif', writer='pillow', fps=4)

plt.show()

# %% [markdown]
# Gif: KL Divergence

# %%
# Setup figure
fig, ax = plt.subplots(figsize=(8, 6))
line, = ax.plot([], [], lw=2)
ax.set_xlabel("Bias Field")
ax.set_ylabel("Expected KL Divergence")
ax.grid(True)

# Initialization function
def init():
    line.set_data([], [])
    return line,

# Animation update function
def update(frame):
    # Assuming bgrid and posteriors are lists/arrays of length 90
    x = f_bias_axis
    y = expectedkl[frame]
    
    # Update data
    line.set_data(x, y)
    
    # Rescale axes dynamically to fit the new zoomed/peaked distribution
    ax.set_xlim(x.min(), x.max())
    ax.set_ylim(0, y.max() * 1.1)
    ax.set_title(f"Expected_KL {frame}")
    return line,

# Create animation (interval in milliseconds)
anim = FuncAnimation(fig, update, frames=len(expectedkl), 
                     init_func=init, blit=False, interval=100)

# Option 2: Save as GIF (No external dependencies usually)
anim.save(f'Tests/Actual/CW/Test_{Test}/KL_Divergence.gif', writer='pillow', fps=4)

plt.show()

# %% [markdown]
# Mode and Std Dev Convergence

# %%
save_path = os.path.join(new_dir, f'Mode Convergence MAP Test {Test}.png'.format(Test))
plt.plot([i for i in range(len(est))], est, label=f"Mode Convergence")
plt.xlabel("N_exp")
plt.ylabel("Mode")
plt.title("Mode Convergence over experiments - Bayesian")
plt.savefig(save_path)
plt.show()


save_path = os.path.join(new_dir, f'Std Convergence MAP Test {Test}.png'.format(Test))
plt.plot([i for i in range(len(stddev))], stddev, label=f"Standard Deviation Convergence")
plt.xlabel("N_exp")
plt.ylabel("Standard Deviation")
plt.title("Standard Deviation Convergence over experiments - Bayesian")
plt.savefig(save_path)
plt.show()

# %% [markdown]
# Ok, Y field estimation by interpolation test.... First we'll have a look at the datasets together and try an interpolation method, measure accuracy and then try the same estimation procedure.

# %%
t_sim, f_sim, by_sim, sim_cube = load_simulation_cube(SIM_FILES_CONFIG_Y_Estimation)
# Out:
# ...Loading Simulation Cube Data...
#   > Axes Loaded: Time[32800], Freq[91], By[12]
#   > Cube Built. Final Shape: (32800, 91, 12)
# Time taken to load sim data: 3.2403111457824707

# %%
interact(plot_slice, by_idx=IntSlider(min=0, max=len(by_sim)-1, step=1, value=0));
# Out:
# interactive(children=(IntSlider(value=0, description='by_idx', max=11), Output()), _dom_classes=('widget-inter…

# %% [markdown]
# Okay, here we validate the interpolation method. The logic is to check for measure of good fit by leaving a point out in each iteration and extrapolating its value from the rest and seeing how well the prediction is. An average is taken over each such iteration corresponding to each point in the domain.

# %%
validate_interpolator(t_sim, f_sim, by_sim, sim_cube)
# Out:
# ...Validating Interpolator...
#   Hold-out By=0.0 | NRMSE: 71.23%
#   Hold-out By=0.1 | NRMSE: 0.35%
#   Hold-out By=0.1 | NRMSE: 0.13%
#   Hold-out By=0.1 | NRMSE: 0.02%
#   Hold-out By=0.2 | NRMSE: 0.01%
#   Hold-out By=0.2 | NRMSE: 0.01%
#   Hold-out By=0.2 | NRMSE: 0.01%
#   Hold-out By=0.2 | NRMSE: 0.00%
#   Hold-out By=0.2 | NRMSE: 0.01%
#   Hold-out By=0.3 | NRMSE: 0.15%
#   Hold-out By=0.4 | NRMSE: 0.49%
#   Hold-out By=0.5 | NRMSE: 2.53%
# --- Average Error: 6.24% ---
# WARNING: Linear Interp has 5-10% error. Consider Cubic.

# %%
sim_interp = get_final_interpolator(t_sim, f_sim, by_sim, sim_cube)
# Out:
# ...Building Final Interpolator...
# Time taken to load Interpolator: 0.1657717227935791

# %% [markdown]
# Plotting Interpolator Predictions

# %%
y_vals = np.linspace(0, 0.5, 10)
Z_mesh, Y_mesh = np.meshgrid(f_sim, y_vals, indexing='ij')
T_mesh = np.full_like(Z_mesh, t_sim[-1])
query_points = np.stack((T_mesh.flatten(), Z_mesh.flatten(), Y_mesh.flatten()), axis=1)
predictions = sim_interp(query_points)
predictions = predictions.reshape(Z_mesh.shape)

plt.figure(figsize=(10,10))
for i in range(len(y_vals)):
    plt.plot(f_sim, predictions[:,i], label=f'Y_val {float(y_vals[i])}')
    plt.ylabel("Normalised Intensity")
    plt.xlabel("Longitudinal Field")
    if i%5==0: plt.legend()
    plt.title("Interpolator Predictions at Final Time Slice, steady state")
plt.show()

# %%
y_vals = np.linspace(0, 0.5, 100)
Z_mesh, Y_mesh = np.meshgrid(f_sim[np.argmax(sim_cube[-1,:,0])], y_vals, indexing='ij')
T_mesh = np.full_like(Z_mesh, t_sim[-1])
query_points = np.stack((T_mesh.flatten(), Z_mesh.flatten(), Y_mesh.flatten()), axis=1)
predictions = sim_interp(query_points)
predictions = predictions.reshape(Z_mesh.shape)

plt.plot(y_vals, predictions[0,:], label=f'Y_val{float(y_vals[i])}')
plt.ylabel("Normalised Intensity")
plt.xlabel("Transverse Y Field")
plt.title("Interpolator Predictions at Final Time Slice for fixed Longitudinal Field ~0")
plt.show()

# %% [markdown]
# Zoom functions are eatly the same right now., please merge them two together and make the code look nice please.

# %%
results_y_estimation = run_experiment_y_estimation(fixed_bz_estimate = 0.06)
# Out:
# ...Starting Adaptive Experiment for Y Estimation...
# ...Loading Simulation Cube Data...
#   > Axes Loaded: Time[32800], Freq[91], By[12]
#   > Cube Built. Final Shape: (32800, 91, 12)
# Time taken to load sim data: 5.023968935012817
# Loading Experiment from DataFiles_to_Dinesh_Pranav\Data_files\Experiment\Probe_trans_Exp.csv...
# 0.04349684715270996 was the time taken to load exp data.
# ...Building Final Interpolator...
# Time taken to load Interpolator: 0.22601580619812012
# 1 580 579 T=5.2 | BiasZ=0.000 | Est By=0.12975 | Std=0.0039
# KL Calculation Time: 0.6332788467407227
# 439 537 98 143.35602862013607
#   [ZOOM] Triggered! Mass concentrated in 98 points.| 0.10975 0.13425 0.0001
#   [ZOOM] Triggered! Mass concentrated in 98 points.| 0.10875 0.13475 4e-05
#   [ZOOM] Res: 0.00025 -> 4e-05 | Grid Size: 2731| 0.006331443786621094 was the time taken to increase resolution. T=5.4 | BiasZ=-0.161 | Est By=0.12325 | Std=0.0041
# KL Calculation Time: 0.7390921115875244
# 436 1096 660 T=5.6 | BiasZ=-0.161 | Est By=0.12025 | Std=0.0032
# KL Calculation Time: 0.7423441410064697
# 436 984 548 T=5.8 | BiasZ=-0.161 | Est By=0.11850 | Std=0.0027
# KL Calculation Time: 0.7701365947723389
# 436 919 483 1206.0188082974346
#   [ZOOM] Triggered! Mass concentrated in 483 points.| 0.10879 0.123734 1.6000000000000003e-05
#   [ZOOM] Res: 4e-05 -> 1.6000000000000003e-05 | Grid Size: 3493| 0.003477334976196289 was the time taken to increase resolution. T=6.0 | BiasZ=-0.161 | Est By=0.11750 | Std=0.0023
# KL Calculation Time: 1.0585551261901855
# 441 1679 1238 T=6.2 | BiasZ=-0.161 | Est By=0.11725 | Std=0.0017
# KL Calculation Time: 1.0946905612945557
# 594 1672 1078 T=6.4 | BiasZ=-0.161 | Est By=0.11775 | Std=0.0014
# KL Calculation Time: 1.1043245792388916
# 777 1679 902 T=6.6 | BiasZ=0.000 | Est By=0.11850 | Std=0.0013
# KL Calculation Time: 1.1078097820281982
# 873 1679 806 T=6.8 | BiasZ=0.000 | Est By=0.11875 | Std=0.0012
# KL Calculation Time: 1.1687443256378174
# 887 1652 765 T=7.0 | BiasZ=0.000 | Est By=0.11875 | Std=0.0011
# KL Calculation Time: 1.1335196495056152
# 923 1634 711 T=7.2 | BiasZ=0.000 | Est By=0.11875 | Std=0.0010
# KL Calculation Time: 1.2037107944488525
# 981 1646 665 T=7.4 | BiasZ=0.000 | Est By=0.11900 | Std=0.0009
# KL Calculation Time: 1.2211012840270996
# 1014 1652 638 T=7.6 | BiasZ=0.000 | Est By=0.11925 | Std=0.0009
# KL Calculation Time: 1.1456024646759033
# 1004 1601 597 T=7.8 | BiasZ=0.000 | Est By=0.11900 | Std=0.0008
# KL Calculation Time: 1.2499022483825684
# 1014 1577 563 T=8.0 | BiasZ=0.000 | Est By=0.11900 | Std=0.0008
# KL Calculation Time: 1.3330154418945312
# 1072 1631 559 T=8.2 | BiasZ=0.000 | Est By=0.11950 | Std=0.0008
# KL Calculation Time: 1.286609411239624
# 1138 1679 541 T=8.4 | BiasZ=0.000 | Est By=0.12025 | Std=0.0008
# KL Calculation Time: 1.3261661529541016
# 1181 1681 500 10823.974516914477
#   [ZOOM] Triggered! Mass concentrated in 500 points.| 0.11775000000000001 0.1237468 6.400000000000001e-06
#   [ZOOM] Res: 1.6000000000000003e-05 -> 6.400000000000001e-06 | Grid Size: 4356| 0.0032019615173339844 was the time taken to increase resolution. T=8.6 | BiasZ=0.000 | Est By=0.12075 | Std=0.0008
# KL Calculation Time: 1.7045965194702148
# 1191 2552 1361 T=8.8 | BiasZ=0.000 | Est By=0.12100 | Std=0.0009
# KL Calculation Time: 1.8137083053588867
# 1409 2568 1159 T=9.0 | BiasZ=0.000 | Est By=0.12150 | Std=0.0008
# KL Calculation Time: 1.765794038772583
# 1581 2577 996 T=9.2 | BiasZ=0.000 | Est By=0.12200 | Std=0.0007
# KL Calculation Time: 1.7789504528045654
# 1694 2585 891 T=9.4 | BiasZ=0.000 | Est By=0.12225 | Std=0.0005
# KL Calculation Time: 1.8288309574127197
# 1842 2593 751 T=9.6 | BiasZ=0.000 | Est By=0.12373 | Std=0.0004
# KL Calculation Time: 1.9109177589416504
# 2004 2609 605 T=9.8 | BiasZ=0.000 | Est By=0.12373 | Std=0.0003
# KL Calculation Time: 1.8622007369995117
# 2106 2617 511 T=10.0 | BiasZ=0.000 | Est By=0.12373 | Std=0.0003
# KL Calculation Time: 1.9784765243530273
# 2149 2641 492 T=10.2 | BiasZ=0.000 | Est By=0.12373 | Std=0.0004
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 results_y_estimation = run_experiment_y_estimation()
#
# Cell In[13], line 176, in run_experiment_y_estimation()
#     173 t_fut_1 = t_next + t_sim_0
#     174 t_fut_2 = t_next + T_STEP + t_sim_0
# --> 176 next_bias, expectedkl = calculate_kl_by(
#     177     posterior_gpu, b_grid_gpu, sim_interp,
#     178     t_fut_1, t_fut_2, f_bias_axis
#     179 )
#     181 history['expectedkl'].append(expectedkl.get())
#     182 curr_bias_z = next_bias
#
# Cell In[9], line 87, in calculate_kl_by(posterior_gpu, by_grid_gpu, sim_interp, t_next_start, t_next_end, candidate_biases_z, batch_size)
#      85 end = min(i+batch_size, n_candidates)
#      86 batch_candidates = z_candidates[i:end]
# ---> 87 mu_matrix_cpu = get_predictions_batch(sim_interp, t_mid, batch_candidates, by_grid_gpu.get())
#      88 mu_matrix_gpu = cp.asarray(mu_matrix_cpu)
#      90 diff_sq = (mu_matrix_gpu[:,None,:] - y_grid_gpu[None, :, None])**2
#
# Cell In[8], line 37, in get_predictions_batch(interpolator, t_pts, z_vals, y_grid)
#      34 T_mesh = np.full_like(Z_mesh, t_pts)
#      36 query = np.stack([T_mesh.flatten(), Z_mesh.flatten(), Y_mesh.flatten()], axis = 1)
# ---> 37 predictions = interpolator(query)
#      38 return predictions.reshape(len(z_vals),len(y_grid))
#
# File c:\Users\Dinesh\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\interpolate\_rgi.py:441, in RegularGridInterpolator.__call__(self, xi, method, nu)
#     439         result = self._evaluate_spline(xi, method)
#     440     else:
# --> 441         result = _spline(xi, nu=nu)
#     443 if not self.bounds_error and self.fill_value is not None:
#     444     result[out_of_bounds] = self.fill_value
#
# File c:\Users\Dinesh\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\interpolate\_ndbspline.py:190, in NdBSpline.__call__(self, xi, nu, extrapolate)
#     178 num_c_tr = c1.shape[-1]  # # of trailing coefficients
#     179 out = _dierckx.evaluate_ndbspline(xi,
#     180                          self._t,
#     181                          self._len_t,
#    (...)    188                          self._indices_k1d,
#     189 )
# --> 190 out = out.view(self.c.dtype)
#     191 return out.reshape(xi_shape[:-1] + self.c.shape[ndim:])
#
# KeyboardInterrupt:

# %%
t,est,stddev,bias,res,posteriors,bgrid,expectedkl = results_y_estimation['time'], results_y_estimation['est'],results_y_estimation['stddev'], results_y_estimation['bias'], results_y_estimation['res'], results_y_estimation['posteriors'], results_y_estimation['bgrids'], results_y_estimation['expectedkl']
result_y_estimation = {
    'time':np.array(t), 
    'est':np.array(est), 
    'stddev':np.array(stddev), 
    'bias':np.array(bias), 
    'res':np.array(res), 
    'posteriors':np.array(posteriors, dtype=object), 
    'bgrids':np.array(bgrid, dtype=object), 
    'expectedkl':np.array(expectedkl, dtype=object)
}
np.savez_compressed(f"Tests/Actual/CW/Transverse_Field_Estimation/Test_{Test}/Transverse_results.npz", **result_y_estimation)
print("Results data saved successfully.")
# Out:
# Results data saved successfully.

# %%
result_longitudinal_estimation = np.load(f"Tests/Actual/CW/Transverse_Field_Estimation/Test_{Test}/Transverse_results.npz", allow_pickle=True)
t,est,stddev,bias,res,posteriors,bgrid,expectedkl = result_longitudinal_estimation['time'], result_longitudinal_estimation['est'],result_longitudinal_estimation['stddev'], result_longitudinal_estimation['bias'], result_longitudinal_estimation['res'], result_longitudinal_estimation['posteriors'], result_longitudinal_estimation['bgrids'], result_longitudinal_estimation['expectedkl']
print("Results data loaded successfully.")
exp_trace_0 = exp_matrix[:,0].flatten()
print(exp_trace_0.shape)
t_exp_0, __ = find_pulse_start(exp_trace_0, t_exp, EXP_PULSE_THRESH)
plot_heat_and_surface((t_exp[__:]-t_exp_0), f_bias_axis, exp_matrix[__:,], trajectory_mode=True,traj_bias = bias)
print(bias)
print(f_bias_axis)
# Out:
# Results data loaded successfully.
# (3119,)
# [ 0.      0.1072  0.1072  0.1072  0.1072 -0.1072 -0.1072 -0.1072 -0.1072
#  -0.1072  0.1072  0.1072  0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072
#  -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072  0.1072
#   0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072  0.1072  0.1072  0.1072
#  -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072  0.1072  0.1072 -0.1072
#  -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072
#  -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072
#  -0.1072 -0.1072  0.1072  0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072
#  -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072
#  -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072
#  -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072
#  -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072
#  -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072
#  -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072 -0.1072]
# [-2.412  -2.3584 -2.3048 -2.2512 -2.1976 -2.144  -2.0904 -2.0368 -1.9832
#  -1.9296 -1.876  -1.8224 -1.7688 -1.7152 -1.6616 -1.608  -1.5544 -1.5008
#  -1.4472 -1.3936 -1.34   -1.2864 -1.2328 -1.1792 -1.1256 -1.072  -1.0184
#  -0.9648 -0.9112 -0.8576 -0.804  -0.7504 -0.6968 -0.6432 -0.5896 -0.536
#  -0.4824 -0.4288 -0.3752 -0.3216 -0.268  -0.2144 -0.1608 -0.1072 -0.0536
#   0.      0.0536  0.1072  0.1608  0.2144  0.268   0.3216  0.3752  0.4288
#   0.4824  0.536   0.5896  0.6432  0.6968  0.7504  0.804   0.8576  0.9112
#   0.9648  1.0184  1.072   1.1256  1.1792  1.2328  1.2864  1.34    1.3936
#   1.4472  1.5008  1.5544  1.608   1.6616  1.7152  1.7688  1.8224  1.876
#   1.9296  1.9832  2.0368  2.0904  2.144   2.1976  2.2512  2.3048  2.3584
#   2.412 ]

# %%
final_posterior = posteriors[-1]
print(est[-1], stddev[-1])
area = np.trapezoid(final_posterior, x = bgrid[-1])
print(f"Final posterior area (should be ~1): {area:.6f}")

plt.figure(figsize=(6, 4))
plt.plot(bgrid[-1][np.argmax(final_posterior) - 1000:np.argmax(final_posterior)+1000], final_posterior[np.argmax(final_posterior) - 1000:np.argmax(final_posterior)+1000], label="final posterior")
plt.xlabel("B")
plt.ylabel("Density")
plt.title("Posterior after adaptive experiment")
plt.legend()
plt.axvline(
    bgrid[-1][np.argmax(final_posterior)],
    color="green",
    linestyle="--",
    label="MAP Estimate",
)
plt.show()
# Out:
# 0.21725 0.00019814426444576865
# Final posterior area (should be ~1): 1.000000

# %% [markdown]
# Posterior GIF

# %%
# Setup figure
fig, ax = plt.subplots(figsize=(8, 6))
line, = ax.plot([], [], lw=2)
ax.set_xlabel("Transverse Magnetic Field B")
ax.set_ylabel("Posterior Probability")
ax.grid(True)

# Initialization function
def init():
    line.set_data([], [])
    return line,

# Animation update function
def update(frame):
    # Assuming bgrid and posteriors are lists/arrays of length 90
    x = bgrid[frame]
    y = posteriors[frame]
    
    # Update data
    line.set_data(x, y)
    
    # Rescale axes dynamically to fit the new zoomed/peaked distribution
    ax.set_xlim(x.min(), x.max())
    ax.set_ylim(0, y.max() * 1.1)
    ax.set_title(f"Posterior Step {frame}")
    return line,

# Create animation (interval in milliseconds)
anim = FuncAnimation(fig, update, frames=len(posteriors), 
                     init_func=init, blit=False, interval=100)

# Option 2: Save as GIF (No external dependencies usually)
anim.save(f'Tests/Actual/CW/Transverse_Field_Estimation/Test_{Test}/Transverse_field_posterior_evolution.gif', writer='pillow', fps=4)

plt.show()

# %% [markdown]
# KL Divergence GIF

# %%
# Setup figure
fig, ax = plt.subplots(figsize=(8, 6))
line, = ax.plot([], [], lw=2)
ax.set_xlabel("Bias Field")
ax.set_ylabel("Expected KL Divergence")
ax.grid(True)

# Initialization function
def init():
    line.set_data([], [])
    return line,

# Animation update function
def update(frame):
    # Assuming bgrid and posteriors are lists/arrays of length 90
    x = f_bias_axis
    y = expectedkl[frame]
    
    # Update data
    line.set_data(x, y)
    
    # Rescale axes dynamically to fit the new zoomed/peaked distribution
    ax.set_xlim(x.min(), x.max())
    ax.set_ylim(0, y.max() * 1.1)
    ax.set_title(f"Expected_KL {frame}")
    return line,

# Create animation (interval in milliseconds)
anim = FuncAnimation(fig, update, frames=len(expectedkl), 
                     init_func=init, blit=False, interval=100)

# Option 2: Save as GIF (No external dependencies usually)
anim.save(f'Tests/Actual/CW/Transverse_Field_Estimation/Test_{Test}/Transverse_Field_KL_Divergence.gif', writer='pillow', fps=4)

plt.show()

# %% [markdown]
# Summary Stats

# %%
save_path = os.path.join(new_dir_y, f'Mode Convergence MAP Transverse Field.png'.format(Test))
plt.plot([i for i in range(len(est))], est, label=f"Mode Convergence")
plt.xlabel("N_exp")
plt.ylabel("Mode")
plt.title("Mode Convergence over experiments - Bayesian")
plt.savefig(save_path)
plt.show()


save_path = os.path.join(new_dir_y, f'Std Convergence MAP Transverse Field.png'.format(Test))
plt.plot([i for i in range(len(stddev))], stddev, label=f"Standard Deviation Convergence")
plt.xlabel("N_exp")
plt.ylabel("Standard Deviation")
plt.title("Standard Deviation Convergence over experiments - Bayesian")
plt.savefig(save_path)
plt.show()

# %%
#Im going to write the code for dead time now, ill copy the run estimation funcition and add dead time as a parameter and also save the results appropriately.

# need to calculate total time and also the experimental time properlyn and accordingly

# %%
MAX_TIME = 30
def run_experiment_longitudinal_estimation_dead_time(fixed_by_estimate = 0.0, t_dead = 0.1):
    print("Starting Adaptive Experiment...")
    #Load Data
    #t_sim, f_sim, sim_spline = load_simulation(SIM_FILES_Longitudinal_Estimation)
    t_sim, f_sim, by_sim, cube = load_simulation_cube(SIM_FILES_CONFIG_Y_Estimation)
    sim_spline = get_final_interpolator(t_sim, f_sim, by_sim, cube)
    t_exp, f_bias_axis, exp_matrix = load_experiment(EXP_FILES)
    f_bias_axis  += F_BIAS_OFFSET_NUISANCE
    
    #Align Time
    print("\nAligning t=0...")
    t_sim_0, _ = find_pulse_start(sim_spline((t_sim, 0, 0)), t_sim, 0.1)
    t_exp_0, __ = find_pulse_start(exp_matrix[:, 0], t_exp, 0.2)
    
    print(f"  > Sim Start: {t_sim_0:.4f}s")
    print(f"  > Exp Start: {t_exp_0:.4f}s")
    
    #Initialization of Grid
    b_grid_gpu = cp.arange(B_UNK_INITIAL_RANGE[0], B_UNK_INITIAL_RANGE[1], INITIAL_RESOLUTION)
    curr_res = INITIAL_RESOLUTION
    #Posterior (Uniform Density)
    #PDF = 1 / (Max - Min)
    pdf_val = 1.0 / (B_UNK_INITIAL_RANGE[1] - B_UNK_INITIAL_RANGE[0])
    posterior_gpu = cp.full_like(b_grid_gpu, pdf_val)
    
    #State
    curr_time = 5.0 #initial data is not nice, hence we are starting after about 5 seconds beyond which the data looks very nice
    curr_bias = 0.0
    
    history = {'time': [], 'est': [], 'stddev' : [], 'bias': [], 'res': [], 'posteriors': [], 'bgrids': [], 'expectedkl' : [], 'dead time': t_dead, 'total time': 0.0}
    history['posteriors'].append(posterior_gpu.get())
    history['bgrids'].append(b_grid_gpu.get())
    
    start_wall = time.time()
    
    # 4. Loop
    while curr_time < MAX_TIME:
        
        # A. Measure 
        t_next = curr_time + T_STEP
        t_start_abs = t_exp_0 + curr_time
        t_end_abs = t_exp_0 + t_next
        
        # Find indices in Exp Matrix
        idx_start = np.searchsorted(t_exp, t_start_abs)
        idx_end = np.searchsorted(t_exp, t_end_abs)

        #FIXME: we can pass candidates array as the f_bias_axis, and that makes sense as far as this data is concerned, fix this after verifying KL divergence 
        bias_idx = (np.abs(f_bias_axis - curr_bias)).argmin()
        
        if idx_start >= idx_end: break # End of data
        
        y_obs = exp_matrix[idx_start:idx_end, bias_idx]
        t_chunk_exp = t_exp[idx_start:idx_end]
        
        #Posterior Update 
        # Map Exp Time -> Sim Time
        t_sim_eval = (t_chunk_exp - t_exp_0) + t_sim_0
          
        likelihood = calculate_likelihood_gpu(
            y_obs, t_sim_eval, curr_bias, fixed_by_estimate, b_grid_gpu, sim_spline, SIGMA_NOISE
        )
        
        posterior_gpu *= likelihood
        norm = cp.trapz(posterior_gpu, x = b_grid_gpu)
        posterior_gpu /= norm
        
        #Adaptive Zoom
        posterior_gpu, b_grid_gpu, curr_res = check_and_apply_zoom(
            posterior_gpu, b_grid_gpu, curr_res
        )
        
        #Record
        # MAP Estimate
        mode,stddev  = calculate_summary_stats(posterior_gpu,b_grid_gpu)
        
        history['time'].append(t_next)
        history['est'].append(mode)
        history['stddev'].append(stddev)
        history['bias'].append(curr_bias)
        history['res'].append(curr_res)
        history['posteriors'].append(posterior_gpu.get())
        history['bgrids'].append(b_grid_gpu.get())
        
        
        print("\n",f"T={t_next:.1f}s | Bias={curr_bias:.3f} | Est={mode:.5f} | Res={curr_res:.1e}", end=" ")
        
        #Adapt Control 
        t_fut_1 = t_next + t_sim_0 + t_dead
        t_fut_2 = t_next + T_STEP + t_sim_0 + t_dead

        
        next_bias, expectedkl = calculate_kl_divergence_gpu(
            posterior_gpu, b_grid_gpu, fixed_by_estimate, sim_spline, 
            t_fut_1, t_fut_2, f_bias_axis, batch_size=131
        )
        
        history['expectedkl'].append(expectedkl.get())
        curr_bias = next_bias +t_dead
        curr_time = t_next
        if stddev <= 1e-4:
            break
        
    print("\n",f"Done in {time.time() - start_wall:.2f}s")
    history['total time'] = time.time() - start_wall
    return history

# %%
def run_experiment_y_estimation_dead_time(fixed_bz_estimate = 0.0, t_dead = 0.1):
    print("...Starting Adaptive Experiment for Y Estimation...")
    t_sim, f_sim, by_sim, cube = load_simulation_cube(SIM_FILES_CONFIG_Y_Estimation)
    t_exp, f_bias_axis, exp_matrix = load_experiment(EXP_FILES)
    sim_interp = get_final_interpolator(t_sim, f_sim, by_sim, cube)
    t_sim_0, _ = find_pulse_start(sim_interp((t_sim, 0, 0)), t_sim, 0.1)
    t_exp_0, _ = find_pulse_start(exp_matrix[:, 0], t_exp, 0.2)

    b_grid_gpu = cp.arange(b_y_bounds[0], b_y_bounds[1], initial_res_by)
    curr_res = initial_res_by

    posterior_gpu = cp.ones_like(b_grid_gpu)
    posterior_gpu /= (cp.sum(posterior_gpu) * curr_res)

    curr_time = 5.0
    curr_bias_z = 0.0

    history = {'time': [], 'est': [], 'stddev' : [], 'bias': [], 'res': [], 'posteriors': [], 'bgrids': [], 'expectedkl' : [], 'dead time': t_dead, 'total time': 0.0}
    history['posteriors'].append(posterior_gpu.get())
    history['bgrids'].append(b_grid_gpu.get())

    start_wall = time.time()
    
    while curr_time < MAX_TIME:
        t_next = curr_time + T_STEP
        t_abs_start = t_exp_0 + curr_time
        t_abs_end = t_exp_0 + t_next
        idx_start = np.searchsorted(t_exp, t_abs_start)
        idx_end = np.searchsorted(t_exp, t_abs_end)
        bias_idx = (np.abs(f_bias_axis - curr_bias_z)).argmin()

        if idx_start >= idx_end: break
        y_obs = exp_matrix[idx_start:idx_end, bias_idx]
        t_chunk_exp = t_exp[idx_start:idx_end]
        t_chunk_sim = (t_chunk_exp - t_exp_0) + t_sim_0

        by_grid_cpu = cp.asnumpy(b_grid_gpu)
        plt.plot(b_grid_gpu.get(), posterior_gpu.get())
        plt.show()

        likelihood = calculate_likelihood_by(
            y_obs, t_chunk_sim, curr_bias_z, by_grid_cpu, sim_interp, SIGMA_NOISE
        )
        
        posterior_gpu *= likelihood
        norm = cp.trapz(posterior_gpu, b_grid_gpu)
        posterior_gpu /= norm

        plt.plot(b_grid_gpu.get(), posterior_gpu.get())
        plt.show()

        posterior_gpu, b_grid_gpu, curr_res = check_and_apply_zoom_by(
            posterior_gpu, b_grid_gpu, curr_res
        )
        
        
        mode,stddev  = calculate_summary_stats(posterior_gpu,b_grid_gpu)
        
        history['time'].append(t_next)
        history['est'].append(mode)
        history['stddev'].append(stddev)
        history['bias'].append(curr_bias_z)
        history['res'].append(curr_res)
        history['posteriors'].append(posterior_gpu.get())
        history['bgrids'].append(b_grid_gpu.get())

        print(f"T={t_next:.1f} | BiasZ={curr_bias_z:.3f} | Est By={mode:.5f} | Std={stddev:.4f}")
        
        t_fut_1 = t_next + t_sim_0 + t_dead
        t_fut_2 = t_next + T_STEP + t_sim_0 + t_dead
        
        next_bias, expectedkl = calculate_kl_by(
            posterior_gpu, b_grid_gpu, sim_interp,
            t_fut_1, t_fut_2, f_bias_axis
        )

        history['expectedkl'].append(expectedkl.get())
        curr_bias_z = next_bias + t_dead
        curr_time = t_next
        if stddev <= 1e-3:
            break

    print("\n",f"Done in {time.time() - start_wall:.2f}s")
    history['total time'] = time.time() - start_wall
    return history

# %%
tdead = [0.0,0.1,0.05, 0.15, 0.2]
for td in tdead:
    MAX_TIME = 30
    results_longitudinal_estimation_dead_time = run_experiment_longitudinal_estimation_dead_time(fixed_by_estimate = 0.13, t_dead = td)

    t,est,stddev,bias,res,posteriors,bgrid,expectedkl, deadtime, totalcomptime = results_longitudinal_estimation_dead_time['time'], results_longitudinal_estimation_dead_time['est'],results_longitudinal_estimation_dead_time['stddev'], results_longitudinal_estimation_dead_time['bias'], results_longitudinal_estimation_dead_time['res'], results_longitudinal_estimation_dead_time['posteriors'], results_longitudinal_estimation_dead_time['bgrids'], results_longitudinal_estimation_dead_time['expectedkl'], results_longitudinal_estimation_dead_time['dead time'], results_longitudinal_estimation_dead_time['total time']
    result_longitudinal_estimation_dead_time = {
        'time':np.array(t), 
        'est':np.array(est), 
        'stddev':np.array(stddev), 
        'bias':np.array(bias), 
        'res':np.array(res), 
        'posteriors':np.array(posteriors, dtype=object), 
        'bgrids':np.array(bgrid, dtype=object), 
        'expectedkl':np.array(expectedkl, dtype=object),
        'dead time': td
    }
    np.savez_compressed(f"Tests/Actual/CW/Test_{Test}/Test_{Test}_results_longitudinal_estimation_dead_time_{td:.2f}s.npz", **result_longitudinal_estimation_dead_time)
    print(f"Results data with dead time {td:.2f}s saved successfully.")

# %%
tdead = [0.0,0.1,0.05, 0.15, 0.2]
for td in tdead:
    MAX_TIME = 30
    results_y_estimation_dead_time = run_experiment_y_estimation_dead_time(fixed_bz_estimate = 0.075, t_dead = td)

    t,est,stddev,bias,res,posteriors,bgrid,expectedkl, deadtime, totalcomptime = results_y_estimation_dead_time['time'], results_y_estimation_dead_time['est'],results_y_estimation_dead_time['stddev'], results_y_estimation_dead_time['bias'], results_y_estimation_dead_time['res'], results_y_estimation_dead_time['posteriors'], results_y_estimation_dead_time['bgrids'], results_y_estimation_dead_time['expectedkl'], results_y_estimation_dead_time['dead time'], results_y_estimation_dead_time['total time']
    result_y_estimation_dead_time = {
        'time':np.array(t), 
        'est':np.array(est), 
        'stddev':np.array(stddev), 
        'bias':np.array(bias), 
        'res':np.array(res), 
        'posteriors':np.array(posteriors, dtype=object), 
        'bgrids':np.array(bgrid, dtype=object), 
        'expectedkl':np.array(expectedkl, dtype=object),
        'dead time': td
    }
    np.savez_compressed(f"Tests/Actual/CW/Test_{Test}/Test_{Test}_results_y_estimation_dead_time_{td:.2f}s.npz", **result_y_estimation_dead_time)
    print(f"Results data with dead time {td:.2f}s saved successfully.")
# Out:
# ...Starting Adaptive Experiment for Y Estimation...
# ...Loading Simulation Cube Data...
#   > Axes Loaded: Time[32800], Freq[91], By[12]
#   > Cube Built. Final Shape: (32800, 91, 12)
# Time taken to load sim data: 3.008028507232666
# Loading Experiment from DataFiles_to_Dinesh_Pranav\Data_files\Experiment\Probe_trans_Exp.csv...
# 0.051568031311035156 was the time taken to load exp data.
# ...Building Final Interpolator...
# Time taken to load Interpolator: 0.15697622299194336
# 1 580 579 T=5.2 | BiasZ=0.000 | Est By=0.12975 | Std=0.0039
# KL Calculation Time: 0.4916384220123291
# 439 537 98 143.35602862013607
#   [ZOOM] Triggered! Mass concentrated in 98 points.| 0.10975 0.13425 0.0001
#   [ZOOM] Triggered! Mass concentrated in 98 points.| 0.10875 0.13475 4e-05
#   [ZOOM] Res: 0.00025 -> 4e-05 | Grid Size: 2731| 0.004999876022338867 was the time taken to increase resolution. T=5.4 | BiasZ=-0.161 | Est By=0.12325 | Std=0.0041
# KL Calculation Time: 0.6150538921356201
# 436 1096 660 T=5.6 | BiasZ=-0.161 | Est By=0.12025 | Std=0.0032
# KL Calculation Time: 0.63484787940979
# 436 984 548 T=5.8 | BiasZ=-0.161 | Est By=0.11850 | Std=0.0027
# KL Calculation Time: 0.6417012214660645
# 436 919 483 1206.0188082974346
#   [ZOOM] Triggered! Mass concentrated in 483 points.| 0.10879 0.123734 1.6000000000000003e-05
#   [ZOOM] Res: 4e-05 -> 1.6000000000000003e-05 | Grid Size: 3493| 0.003999948501586914 was the time taken to increase resolution. T=6.0 | BiasZ=-0.161 | Est By=0.11750 | Std=0.0023
# KL Calculation Time: 0.8386290073394775
# 441 1679 1238 T=6.2 | BiasZ=-0.161 | Est By=0.11725 | Std=0.0017
# KL Calculation Time: 0.8587980270385742
# 594 1672 1078 T=6.4 | BiasZ=-0.161 | Est By=0.11775 | Std=0.0014
# KL Calculation Time: 0.8819925785064697
# 777 1679 902 T=6.6 | BiasZ=0.000 | Est By=0.11850 | Std=0.0013
# KL Calculation Time: 0.9010279178619385
# 873 1679 806 T=6.8 | BiasZ=0.000 | Est By=0.11875 | Std=0.0012
# KL Calculation Time: 0.9251382350921631
# 887 1652 765 T=7.0 | BiasZ=0.000 | Est By=0.11875 | Std=0.0011
# KL Calculation Time: 0.9492499828338623
# 923 1634 711 T=7.2 | BiasZ=0.000 | Est By=0.11875 | Std=0.0010
# KL Calculation Time: 0.9658713340759277
#
#  Done in 11.34s
# Results data with dead time 0.00s saved successfully.
# ...Starting Adaptive Experiment for Y Estimation...
# ...Loading Simulation Cube Data...
#   > Axes Loaded: Time[32800], Freq[91], By[12]
#   > Cube Built. Final Shape: (32800, 91, 12)
# Time taken to load sim data: 2.9418349266052246
# Loading Experiment from DataFiles_to_Dinesh_Pranav\Data_files\Experiment\Probe_trans_Exp.csv...
# 0.05066084861755371 was the time taken to load exp data.
# ...Building Final Interpolator...
# Time taken to load Interpolator: 0.1556992530822754
# 1 580 579 T=5.2 | BiasZ=0.000 | Est By=0.12975 | Std=0.0039
# KL Calculation Time: 0.4914681911468506
# 0 23 23 1923.5548189066872
#   [ZOOM] Triggered! Mass concentrated in 23 points.| 0.0 0.0057 0.0001
#   [ZOOM] Triggered! Mass concentrated in 23 points.| 0.0 0.006240000000000001 4e-05
#   [ZOOM] Triggered! Mass concentrated in 23 points.| 0.0 0.0067360000000000015 1.6000000000000003e-05
#   [ZOOM] Res: 0.00025 -> 1.6000000000000003e-05 | Grid Size: 2568| 0.008129119873046875 was the time taken to increase resolution. T=5.4 | BiasZ=-0.061 | Est By=0.00000 | Std=0.0010
# KL Calculation Time: 0.5858309268951416
#
#  Done in 1.43s
# Results data with dead time 0.10s saved successfully.
# ...Starting Adaptive Experiment for Y Estimation...
# ...Loading Simulation Cube Data...
#   > Axes Loaded: Time[32800], Freq[91], By[12]
#   > Cube Built. Final Shape: (32800, 91, 12)
# Time taken to load sim data: 2.9834437370300293
# Loading Experiment from DataFiles_to_Dinesh_Pranav\Data_files\Experiment\Probe_trans_Exp.csv...
# 0.051284074783325195 was the time taken to load exp data.
# ...Building Final Interpolator...
# Time taken to load Interpolator: 0.15726041793823242
# 1 580 579 T=5.2 | BiasZ=0.000 | Est By=0.12975 | Std=0.0039
# KL Calculation Time: 0.43877339363098145
# 0 47 47 795.3756887475636
#   [ZOOM] Triggered! Mass concentrated in 47 points.| 0.0 0.0117 0.0001
#   [ZOOM] Triggered! Mass concentrated in 47 points.| 0.0 0.01272 4e-05
#   [ZOOM] Triggered! Mass concentrated in 47 points.| 0.0 0.013488000000000002 1.6000000000000003e-05
#   [ZOOM] Res: 0.00025 -> 1.6000000000000003e-05 | Grid Size: 3141| 0.007016897201538086 was the time taken to increase resolution. T=5.4 | BiasZ=-0.111 | Est By=0.00000 | Std=0.0025
# KL Calculation Time: 0.7079172134399414
# 0 1197 1197 T=5.6 | BiasZ=0.104 | Est By=0.00000 | Std=0.0028
# KL Calculation Time: 0.7254173755645752
# 0 1204 1204 T=5.8 | BiasZ=0.104 | Est By=0.00150 | Std=0.0037
# KL Calculation Time: 0.7371292114257812
# 0 1205 1205 T=6.0 | BiasZ=0.104 | Est By=0.01160 | Std=0.0026
# KL Calculation Time: 0.7526016235351562
# 0 1204 1204 T=6.2 | BiasZ=0.104 | Est By=0.01140 | Std=0.0022
# KL Calculation Time: 0.7755165100097656
# 340 1211 871 T=6.4 | BiasZ=-0.111 | Est By=0.01170 | Std=0.0012
# KL Calculation Time: 0.7951807975769043
# 661 1221 560 T=6.6 | BiasZ=-0.111 | Est By=0.01272 | Std=0.0008
# KL Calculation Time: 0.808403730392456
#
#  Done in 7.62s
# Results data with dead time 0.05s saved successfully.
# ...Starting Adaptive Experiment for Y Estimation...
# ...Loading Simulation Cube Data...
#   > Axes Loaded: Time[32800], Freq[91], By[12]
#   > Cube Built. Final Shape: (32800, 91, 12)
# Time taken to load sim data: 2.9172332286834717
# Loading Experiment from DataFiles_to_Dinesh_Pranav\Data_files\Experiment\Probe_trans_Exp.csv...
# 0.0479738712310791 was the time taken to load exp data.
# ...Building Final Interpolator...
# Time taken to load Interpolator: 0.15599989891052246
# 1 580 579 T=5.2 | BiasZ=0.000 | Est By=0.12975 | Std=0.0039
# KL Calculation Time: 0.49599123001098633
# 0 440 440 T=5.4 | BiasZ=-0.011 | Est By=0.00000 | Std=0.0014
# KL Calculation Time: 0.45729756355285645
# 0 50 50 731.4822040334161
#   [ZOOM] Triggered! Mass concentrated in 50 points.| 0.0 0.012400000000000001 0.0001
#   [ZOOM] Triggered! Mass concentrated in 50 points.| 0.0 0.013720000000000001 4e-05
#   [ZOOM] Triggered! Mass concentrated in 50 points.| 0.0 0.014736000000000003 1.6000000000000003e-05
#   [ZOOM] Res: 0.00025 -> 1.6000000000000003e-05 | Grid Size: 3244| 0.00611424446105957 was the time taken to increase resolution. T=5.6 | BiasZ=0.204 | Est By=0.00000 | Std=0.0028
# KL Calculation Time: 0.7536766529083252
# 0 1308 1308 T=5.8 | BiasZ=0.204 | Est By=0.00000 | Std=0.0027
# KL Calculation Time: 0.7745730876922607
# 0 1310 1310 T=6.0 | BiasZ=0.204 | Est By=0.00000 | Std=0.0022
# KL Calculation Time: 0.7913353443145752
# 0 474 474 47414.24184184757
#   [ZOOM] Triggered! Mass concentrated in 474 points.| 0.0 0.005248000000000001 6.400000000000001e-06
#   [ZOOM] Res: 1.6000000000000003e-05 -> 6.400000000000001e-06 | Grid Size: 3947| 0.004016876220703125 was the time taken to increase resolution. T=6.2 | BiasZ=-0.011 | Est By=0.00000 | Std=0.0006
# KL Calculation Time: 0.9855115413665771
#
#  Done in 5.52s
# Results data with dead time 0.15s saved successfully.
# ...Starting Adaptive Experiment for Y Estimation...
# ...Loading Simulation Cube Data...
#   > Axes Loaded: Time[32800], Freq[91], By[12]
#   > Cube Built. Final Shape: (32800, 91, 12)
# Time taken to load sim data: 2.8726446628570557
# Loading Experiment from DataFiles_to_Dinesh_Pranav\Data_files\Experiment\Probe_trans_Exp.csv...
# 0.04805254936218262 was the time taken to load exp data.
# ...Building Final Interpolator...
# Time taken to load Interpolator: 0.15607619285583496
# 1 580 579 T=5.2 | BiasZ=0.000 | Est By=0.12975 | Std=0.0039
# KL Calculation Time: 0.4858663082122803
# 0 23 23 1485.8136866302884
#   [ZOOM] Triggered! Mass concentrated in 23 points.| 0.0 0.0057 0.0001
#   [ZOOM] Triggered! Mass concentrated in 23 points.| 0.0 0.006240000000000001 4e-05
#   [ZOOM] Triggered! Mass concentrated in 23 points.| 0.0 0.006496000000000001 1.6000000000000003e-05
#   [ZOOM] Res: 0.00025 -> 1.6000000000000003e-05 | Grid Size: 2553| 0.0060236454010009766 was the time taken to increase resolution. T=5.4 | BiasZ=0.039 | Est By=0.00000 | Std=0.0010
# KL Calculation Time: 0.5862467288970947
#
#  Done in 1.42s
# Results data with dead time 0.20s saved successfully.
